# %% [markdown]
# # [Topic Modeling](https://towardsdatascience.com/topic-modeling-and-latent-dirichlet-allocation-in-python-9bf156893c24)

# %%
from pprint import pprint
import numpy as np
np.random.seed(2018)
import nltk

# reload only imported modules before run
# https://ipython.org/ipython-doc/3/config/extensions/autoreload.html
# %load_ext autoreload
# %autoreload 2

'''
pantree bank tags: https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html
standford source: https://nlp.stanford.edu/software/CRF-NER.shtml
standford online text tree generater: http://nlp.stanford.edu:8080/parser/index.jsp
'''
# Out:
# '\npantree bank tags: https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html\nstandford source: https://nlp.stanford.edu/software/CRF-NER.shtml\nstandford online text tree generater: http://nlp.stanford.edu:8080/parser/index.jsp\n'

# %% [markdown]
# ### constants

# %%
start_date = '01-11-2018' #  09-Sep-2018 
end_date = '30-12-2018' # 01-Oct-2018

# %% [markdown]
# ### We will perform the following steps:
#
# #### 1. Tokenization:
# Split the text into sentences and the sentences into words. Lowercase the words and remove punctuation.

# %%
# def tokenize(text):
#     return gensim.utils.simple_preprocess(text)

# %% [markdown]
# #### 2. Remove small words:
# Words that have fewer than 3 characters are removed.

# %%
# def isShortWord(token):
#     return len(token) < 3

# %% [markdown]
# #### 3. Remove stopwords:
# All stopwords are removed.

# %%
# def isStopWord(token):
#     return token in gensim.parsing.preprocessing.STOPWORDS

# %% [markdown]
# #### 4. lemmatized +  Stemming:
# Words are lemmatized — words in third person are changed to first person and verbs in past and future tenses are changed into present.
#
# Words are stemmed — words are reduced to their root form.

# %%
# from nltk.corpus import wordnet as wn
# from nltk import pos_tag, word_tokenize
# from nltk.stem.porter import *
# from textblob import TextBlob


# def lemmatize_stemming(token):
#     stemmer = PorterStemmer() #gensim.parsing.stem_text(tokenize) #
#     for word, tag in pos_tag(word_tokenize(token)):
#         wntag = tag[0].lower()
#         wntag = wntag if wntag in ['a', 'r', 'n', 'v'] else None
#         lemma = WordNetLemmatizer().lemmatize(word, wntag) if wntag else word
#         return TextBlob(lemma).words[0].singularize()
#     return ''

# %% [markdown]
# #### 5. Replace Emojis:

# %%
# ## get emoji characters file path
# def getEmojis():
#     from dataSource import getEmojis
#     comments_file_path = getDataSourcePathFor(emoji_path)
#     return getEmojis(comments_file_path)#.head()

# %%
# def hasEmojicon(token):
    
# def replaceEmojicons(token, emojies):
#     pass

# %% [markdown]
# ## Data Source

# %%
# def getNounList(sentence='', tokens = []):
#     from nltk import word_tokenize, pos_tag
#     if len(tokens) > 0:    
#         nouns = [token for token, pos in pos_tag(tokens) if pos.startswith('NN')]
#         return nouns
#     else:
#         nouns = [token for token, pos in pos_tag(word_tokenize(sentence)) if pos.startswith('NN')]
#         return nouns

# %%
# text = 'I Have done reviewing, Will be seeing by them'
# print(preprocess(text))

# %%
# key is file storage path
# def getDataSourcePathFor(keyForFilePath):
#     import json
#     import os
    
#     config_file_path = os.environ[virtual_env] + '/config.json'

#     with open(config_file_path) as f:
#         config = json.load(f)
#         if keyForFilePath in config:# ['comments_path', 'output_path']
#             return config[keyForFilePath] 
#     return None

# %%
# ## get list of comments from stored input csv file
# import dataSource 

# def getListOfComments():
#     ### This is to get csv rows between given dates
#     comments_file_path = getDataSourcePathFor(comments_path)
#     commentsList = getComments(comments_file_path, start_date, end_date) #['comments'] 
#     commentsList = commentsList.sort_values(by='ratings', ascending=True)['comments'] 
#     print('Total number of comments: %s between %s and %s' % (len(commentsList), start_date, end_date))
#     return commentsList

# %% [markdown]
# ### Text processing

# %%
# import re

# def filterWord(token):
#     if not (isStopWord(token) or isShortWord(token)):
#         lemmaWord = lemmatize_stemming(token)
#         if not isShortWord(lemmaWord):
#             return ("".join(re.findall("[a-zA-Z]+", lemmaWord)).lower())
#     return None 
    
# def filters(sentence):
# #     print('..given comments:', sentence)
#     result = []
#     #nouns = getNounList(sentence) # fetch only Nouns
#     for token in tokenize(sentence):#nouns: ###tokenize(text):
#         result.append(filterWord(token))
#     return result

# def filterWords(tokens):
#     return list(filter(lambda token: filterWord(token), tokens))

# %%
# def preprocessCommentDocument(document):
#     return list(map(lambda sentence: filters(sentence), document))

# %% [markdown]
# ### Word Cloud

# %%
from wordCloud import showWordCloud
def showCloud(topicCollection):
    showWordCloud(topicCollection)

# %% [markdown]
# ### Bag of Words on the Data set

# %%
def bow(processed_docs):
    dictionary = gensim.corpora.Dictionary(processed_docs)
    bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
    return bow_corpus

# %% [markdown]
# ### Sentiment

# %%
from getSentiment import getSentiment

def getSentFromCommentList(commentList):
    sentimentList = []
    for sentence in commentList:
        sentiment = getSentiment(sentence)
        sentimentList.append(sentiment)
    return sentimentList


def isNegative(sentiment):
    return sentiment > 0.5


def tokenDictWithPosNegSentiment(sentimentList, document):
    sentDict = {}
    size = range(len(document))
    
    for i in size:
        for token in document[i]:
            v = (0, 0, 0) # (neg, pos, freq)
            if token in sentDict:
                v = sentDict[token]
                
            if isNegative(sentimentList[i]):
                v = (v[0]+1, v[1], v[2]+1)
            else:
                v = (v[0], v[1]+1, v[2]+1)
            sentDict[token] = v
    sentDict.pop('', None)
    return sentDict

# %% [markdown]
# ### Main()

# %%
import SDataSource
import SConstants
from SWordList import SWordList
from sUtility import SUtility
from sPreprocessor import SPreprocessor

# %%
sutility = SUtility()
spreprocessor = SPreprocessor()

# SPreprocessor.resolveDependancy(trieCommon)
dateBetween = [start_date, end_date]
commentsDocument = SDataSource.getListOfComments(dateBetween)#.head(1000)
print('filtered comments: ', len(commentsDocument))
# document preprocessing, cleaning, filtering, replacement, spliting into multiple senetnces from one
processed_doc = []
for sentence in commentsDocument:
    for each in spreprocessor.docCleaning(sentence, False): #should split by ','
        processed_doc.append(each)
# Out:
# Total number of comments: 972 between 01-11-2018 and 30-12-2018
# filtered comments:  320

# %%
def makeDict(sentence):
    t = spreprocessor.parseToTokens(trieTopic, sentence)
    r = spreprocessor.parseToTokens(trieNReason, sentence)
    print(sentence)
    print('topic is:', t)
    print('reasons are:', r)
    print()
    sutility.dump(t, r)

# %%
wordList_file = SDataSource.getDataSourcePathFor(SConstants.wordFile_path)
trieCommon = SWordList(wordList_file)

topic_file = SDataSource.getDataSourcePathFor(SConstants.topic_path)
trieTopic = SWordList(topic_file)

n_reason_file = SDataSource.getDataSourcePathFor(SConstants.n_reason_path)
trieNReason = SWordList(n_reason_file)
# Out:
# ..SWordList constructor called
# ..SWordList constructor called
# ..SWordList constructor called

# %%
l = ['crashing', 'changes', 'upi', 'biometric']
print(spreprocessor.filterWords(l))
# Out:
# ['crash', 'chang', 'upi', 'biometr']

# %%
for each in processed_doc:
    makeDict(each)
# Out:
# i am cant add amount from another upi acoount or also cant transfer from another banks account it shows me benificary account is inactive or major problem not setup a upi id
# topic is: ['upi', 'account']
# reasons are: ['add amount', 'transfer', 'inact', 'problem']
#
# now i am facing another problemi cant login dont know why solve the problem as soon as possible
# topic is: ['login']
# reasons are: ['face', 'problem']
#
# the lastest update broke the app
# topic is: ['updat', 'app']
# reasons are: ['broke']
#
# kya yr debit card se funds load nai kar sakte ismekoi kaam ka nai hai ye bank fir
# topic is: ['debit card']
# reasons are: []
#
# sir app is not open and ifsc of most of the bank dont reflect it was my favorite app but not now
# topic is: ['app', 'ifsc']
# reasons are: ['open', 'reflect']
#
# hating your services your technical issues were dont ending  highly absence of technological advances now required to stop your services immediately not qualified for asia best bank where as must be qualified for asia worst bank lets enjoy the worst bank tag
# topic is: []
# reasons are: ['servic', 'technical issues', 'stop', 'not qualified', 'worst bank']
#
# i have been trying to get kyc done since one month but no agent is calling even after submitting
# topic is: ['kyc']
# reasons are: []
#
# worst experience  customer service disappointed
# topic is: ['customer service']
# reasons are: ['worst experience', 'servic']
#
# very slow app
# topic is: ['app']
# reasons are: []
#
# first of all give the best service dont give  minutes account open just one tap i given request for account open last  months back till no response bad service  dont waste time
# topic is: ['account']
# reasons are: ['servic', 'open', 'bad']
#
# my account was dormant for few months now when i activated it applied new atm card but unable to add transfer any funds but still i am cant fund my account pls activate it i would like to use and give a  star review pls activate it
# topic is: ['account', 'atm']
# reasons are: ['dormant', 'transfer']
#
# its not showing that how to apply debit card in this app not there option
# topic is: ['debit card', 'app']
# reasons are: []
#
# poor server issue i was trying from last  hr to login and i am cant do i have tried on g and on my home wifi also
# topic is: ['login']
# reasons are: ['server issue']
#
# app update cant logingetting problems feeling bad
# topic is: ['app', 'updat']
# reasons are: ['bad']
#
# i open application but its showing something wrong please check network and secure connectivity
# topic is: []
# reasons are: ['open', 'something wrong']
#
# customer service not support
# topic is: ['customer service']
# reasons are: ['servic']
#
# crashes my mobile all the time and unable to reset my password with correct credentials but says not matched dont download
# topic is: []
# reasons are: ['crash', 'reset', 'correct credentials']
#
# fund account when if use net banking option they display only half screen log id bas sachin tendulkar brand ambestor hai isliye bharosa hai
# topic is: ['account']
# reasons are: ['screen']
#
# worst experience cant login even after resetting my password for almost  times
# topic is: ['login']
# reasons are: ['worst experience', 'reset']
#
# such a worst app always showing popup menu for update kyc here in ahmedabad dont have branch but it irritate everytime of app open
# topic is: ['app', 'updat', 'kyc']
# reasons are: ['popup', 'open']
#
# after recent update cant login also it kerps rotating but doesnt login
# topic is: ['updat', 'login']
# reasons are: []
#
# yet upi problem is not fixed its been almost a month and dbs is a online banking
# topic is: ['upi']
# reasons are: ['problem', 'not fixed']
#
# this is not open account
# topic is: ['account']
# reasons are: ['open']
#
# no agent contacted me for kyc verification
# topic is: ['kyc']
# reasons are: []
#
# i am unable set my new atm pin
# topic is: ['atm']
# reasons are: []
#
# im uninstalling this app since no option to add money from debit cards also new version of this app sucks
# topic is: ['app', 'debit cards', 'version']
# reasons are: ['suck']
#
# why it asking update your app i need older version so kindly provide old version in all app its depend we need to update means then only we can update right but here at any cost we need update other wise it will not open older version
# topic is: ['updat', 'app', 'version']
# reasons are: ['open']
#
# it had unique feature fund from debit card but the recent updates removed that feature so it is common like other bank so i suggest to add the feature back
# topic is: ['debit card']
# reasons are: []
#
# i need help the worst thing i feel there is no customer care no i forgot my username and password and now cant reset it after putting my personal information the app does nothing please help
# topic is: ['customer care', 'app']
# reasons are: ['reset']
#
# i like digibank and using this app for almost a year or  but recently i am facing some strange login issue whedont i login it treats the device as new device and asks me to complete the registration process i have done it for more than  times and now i am fed up of this this could be the device id issue as i am on android
# topic is: ['app', 'login']
# reasons are: ['face']
#
# worst of the worst app its crashing my whole phone whedont i open the app and its restarting every time i would like to give  stars for this app
# topic is: ['app']
# reasons are: ['crash', 'open', 'every time']
#
# everytime i login its shows now get your visa paywave debit card  service not available in my area the page stuck on that i am cant close it how could i use the app worst experience
# topic is: ['login', 'debit card', 'app']
# reasons are: ['servic', 'stuck', 'worst experience']
#
# after the new update cant sign in
# topic is: ['updat']
# reasons are: []
#
# app is not open showing error msg something went wrong please try again with secure network
# topic is: ['app']
# reasons are: ['open', 'something went wrong']
#
# i am citizen of india and not allowed to vote why our system is so weak  being a teacher living in hyderabad for past  plus years i am cant vote  this is shame for nation
# topic is: []
# reasons are: []
#
# the latest update is throwing a popup dbs india stoppedtry resolving the issue
# topic is: ['updat']
# reasons are: ['popup']
#
# unable to login to app gives something is weong error pathetic app can you fix it asap
# topic is: ['login', 'app']
# reasons are: ['fix it']
#
# i am cant do upi transaction on this ac why i cant set upi
# topic is: ['upi']
# reasons are: []
#
# every time when i logged in showing every time to create new upi handle why i hv created it already though it is showing to create new upi again and again
# topic is: ['upi']
# reasons are: ['every time']
#
# the worst mobile banking app i have ever seen
# topic is: ['app']
# reasons are: []
#
# i was referred by one of my friend to open an account after downloading the app when i put my credentials i am cant sumbit the application to complete account open formalities which is very bad on the first time later if i am using virtual assistance it is of no use because dont get proper answers to the desired queries asked very bad experience before completing the account formalities and now to login as well
# topic is: ['account', 'app', 'login']
# reasons are: ['open', 'bad']
#
# why are you forcing to take debit cardit says pls change postal code to get debit cardi dont want atm pls allow me to my account
# topic is: ['postal code', 'atm', 'account']
# reasons are: ['forc', 'chang']
#
# dont install card shipping service not available in rajkot gujrat
# topic is: []
# reasons are: ['servic']
#
# i am cant use debit card for international transactions i am not able add my card to paypal
# topic is: ['debit card', 'international transactions']
# reasons are: []
#
# unable to signup for last hour i dont use my contact details with dbs and its reflecting already exist details
# topic is: ['signup']
# reasons are: ['contact details', 'reflect']
#
# very buggy after the new nov  update
# topic is: ['updat']
# reasons are: ['buggi']
#
# not allowing to login showing error something went wrong please try again with secure network i tried all possible ways ie cleared data uninstalled and reinstalled but no luck please anyone help need to do urgent transaction money got stuck in it
# topic is: ['login']
# reasons are: ['something went wrong', 'stuck']
#
# making fraud and and wrongly deducted my rs  in my account
# topic is: ['account']
# reasons are: ['wrong', 'deduct']
#
# my first transaction is successful but second transaction not success its bad app
# topic is: ['app']
# reasons are: ['bad']
#
# everytime i open the app it say register ur new device  plz fix it
# topic is: ['app']
# reasons are: ['open', 'fix it']
#
# really sad to hear that i have to visit the branch in other city ie  hours journey from hyderabadfor just activating account for which i already submitted biometric at the time of account open
# topic is: ['account', 'biometr']
# reasons are: ['open']
#
# its rd class app the worst app i ever seen
# topic is: ['app']
# reasons are: []
#
# app is not working
# topic is: ['app']
# reasons are: ['not working']
#
# whats the wrong with this app  i cant login to my account it says you have forgot your password even when i enter correct passwordand when i try to reset my password it says you cant change your password  how can u login to my account
# topic is: ['app', 'login', 'account']
# reasons are: ['reset', 'chang']
#
# time to say goodbye to digi  removing add debit card option only loose customer nothing else all digital banks are using add fund through debit card and all time upi is not possible at all surely people will switch to  kotak digi must return the feature
# topic is: ['debit card', 'upi']
# reasons are: []
#
# wouldnt let me login keeps telling oops something went wrongtry again from a safer network
# topic is: ['login']
# reasons are: []
#
# app was working good until today app is crashing after the update please resolve it
# topic is: ['app', 'updat']
# reasons are: ['crash']
#
# no star new version we dont have option to credit the wallet with debit card and credit card if so what is use of thisall will not have net banking and upi optioncan u explain what is use of this why we need to use your app
# topic is: ['version', 'debit card', 'upi', 'app']
# reasons are: []
#
# opened my account and i forgot my password now i am trying to change password i am receiving otp but cant see next screen to enter or capture otp on mobile and on web it is sowing there is error we are trying to fix it when i tried changing password its major bug and developers are not doing anything useless bank app i cant deposite money even after open an account
# topic is: ['account', 'app']
# reasons are: ['chang', 'screen', 'fix it', 'deposit', 'open']
#
# deals and offers are showing worst case
# topic is: ['deals and offers', 'offer']
# reasons are: []
#
# i cant login they said password is incorrect but when i try to reset password i cant its stuck there then i change password from website but on app still i cant login
# topic is: ['login', 'app']
# reasons are: ['incorrect', 'reset', 'stuck', 'chang']
#
# it is not user friendly login problem and money loading problem
# topic is: ['login']
# reasons are: ['problem']
#
# unable to change category in transaction and the app look is very boring please update it very very slow compared to other banking apps sometimes the back option not working the app really sucks
# topic is: ['app', 'look', 'updat', 'back option']
# reasons are: ['chang', 'not working', 'suck']
#
# it is not open i dont know why always gives an error of technical issues even i dont get messages debit or credit
# topic is: []
# reasons are: ['open', 'technical issues']
#
# why i cant cancel the yellow page now get your visa paywave debit card i cant proceed also because it is not available in my stateand i dont want a physical card so why that page not cancelling
# topic is: ['debit card']
# reasons are: []
#
# i dont like update again and again
# topic is: ['updat']
# reasons are: []
#
# worst banking app used ever
# topic is: ['app']
# reasons are: []
#
# vpa not fixed
# topic is: []
# reasons are: ['not fixed']
#
# when im resetting my accounts password it shows me something went wrong please solve this problem
# topic is: []
# reasons are: ['reset', 'something went wrong', 'problem']
#
# after updating the app it askede to login but i forgot my user idi clicked on forgot user id optionit asked me to enter my mobile number and email idi gave my number email id and i clicked on nextbut it is not respondingit is not going to next screenhow can i get my user id
# topic is: ['app', 'login']
# reasons are: []
#
# worst experience i ever had
# topic is: []
# reasons are: ['worst experience']
#
# west
# topic is: []
# reasons are: []
#
# highly unstable application
# topic is: []
# reasons are: ['unstabl']
#
# i have done a upi transaction and they showed that it is successful but amount did not credited to beneficiary and also the didnt replied of my mail totally frustrating app very slow
# topic is: ['upi', 'app']
# reasons are: ['frustrat']
#
# money add option not available from debit card in new update externally worst experience not best use of new app
# topic is: ['debit card', 'updat', 'app']
# reasons are: ['worst experience']
#
# unable to loginalways ask to set new password
# topic is: []
# reasons are: []
#
# app asks for upi although ive already done it twice it doesnt let you by pass the upi registration page to go the main screen
# topic is: ['app', 'upi']
# reasons are: ['screen']
#
# i done lot of transactions and lways have handsome balance amount in account alsk have great credit score but dont get option for personal loan
# topic is: ['balanc', 'account']
# reasons are: []
#
# app is again and again taking me to the upi vpa page as soon as i login even after creation of upi address the app again asks for upi details on next login and i am unable to access anything on the app i have updated the app as well hoping it will resolve the issue but no luck please provide an update to fix the issue
# topic is: ['app', 'upi', 'login', 'updat']
# reasons are: []
#
# very very slow appworst for banking please consider customer feedback  do the needful
# topic is: []
# reasons are: []
#
# the current update on this app is disgusting the developer has added a popup ad when you login takes away most of the time keeps hanging this has become a big headache to handle especially when you depend on this bank
# topic is: ['updat', 'app', 'login']
# reasons are: ['popup']
#
# you call yourself asias safest bank and all that nonsence but your app is probably not just asia but worlds slowest and most sluggish app the whole experience of online banking becomes pathetic with this rediculous appvery dissappointed with the way you people have build this app super slow sluggish and unstable very bad experience please do something
# topic is: ['app']
# reasons are: ['unstabl', 'bad']
#
# first is app is very low lots of time i updated app but till now app is slowwhen i registered in digibank there was a mistake in my name spelling for my aadhar card spelling was wrong but lots of time i tried replace my name spelling but i could not do itso bad experience last things always tell   interest rate but totally fake interest rate if you invest for  year then highest  not   totally fake
# topic is: ['app', None]
# reasons are: ['bad']
#
# after an update its working worse i m trying to change my contact number from  days but every time there occurs an error
# topic is: ['updat']
# reasons are: ['chang', 'every time']
#
# worst
# topic is: []
# reasons are: []
#
# bad experience none come for my biometric confirmation the app contains full of bugs and caches  app damage phone data  redmi phone didnt support this app
# topic is: ['biometr', 'app']
# reasons are: ['bad']
#
# pathetic app ever used why dbs is not working on improving this app frustrated now closing my account with dbs shortly
# topic is: ['app', 'account']
# reasons are: ['not working', 'frustrat']
#
# worst experience after update app
# topic is: ['updat', 'app']
# reasons are: ['worst experience']
#
# i sent many email but i have not received any reply from your side reply me asap otherwise get ready for negative feedbacks
# topic is: []
# reasons are: []
#
# i dont know y made like this that app can operate from same sim in and same phone  taken all the permission  even if we disagree they wont allow to register
# topic is: ['app']
# reasons are: []
#
# the app is too slow and freezes frequently the day it came on play store not a single time you people bothered to update the app to improve its smoothness the app is developed in its worst way and instead you are taking around mb for this app
# topic is: ['app', 'updat']
# reasons are: []
#
# one of the worst app in play storepls play dont allow to upload such kind of fake app thanks
# topic is: ['app']
# reasons are: []
#
# you call yourself asias safest bank and all that nonsence but your app is probably not just asia but worlds slowest and most sluggish app the whole experience of online banking becomes pathetic with this rediculous appvery dissappointed with the way you people have build this app super slow sluggish and unstable very bad experience please do something
# topic is: ['app']
# reasons are: ['unstabl', 'bad']
#
# pathetic app i have my old phone nd old number but it is still considering it new and im unable to login the app failing again and again i wish to withdrawl my all amount and uninstall the app now
# topic is: ['app', 'login']
# reasons are: []
#
# i am always getting error message to order debit card once i logged in i am unable to close this window i am unable to do any banking because of this huge error this app need to be improved
# topic is: ['debit card', 'app']
# reasons are: []
#
# cant use this and load money using debit card
# topic is: ['debit card']
# reasons are: []
#
# money not added from debit card fully faltu because other bank se payment digi bank per transfer karake other account pe transfer karange to pahile hi banks se other bank ko money transfer karenge to digi bank ka isme ky kam hai sagar kisika netbanking chalu nahi hai to usake account se money kase add karengeso funny and fully faltu
# topic is: ['debit card', 'account']
# reasons are: ['transfer']
#
# the upi linking is not workinghow i supposed to be add money through upiplzzz fixxx it asap
# topic is: ['upi']
# reasons are: []
#
# no option to add money from card in new updation  this new version is not improved some previous options are removed in this new version really sad
# topic is: ['version']
# reasons are: []
#
# very unpleasant experience im using one phone for this app but every time at login this app it shows login with a new phone and otp based verification  even my upi page missing for some time after login digi bank is a app based bank with such errors i m going to deactivate my account
# topic is: ['app', 'login', 'upi', 'account']
# reasons are: ['every time']
#
# terrible service from customer team for verification in app and website they have given many options like someone will come to your address and complete or visit some ccd and stuffs like that but in reality main city regions in surat they are telling like the area is inaccessible though in app its serviceable and apparently ccd and other stuffs are also just hoax now the only option is going  km far to their brach to do the verification apparently they think we have no other job
# topic is: ['app']
# reasons are: ['servic']
#
# this facility is not present in hyderabad
# topic is: []
# reasons are: []
#
# i was asked to run an update by the app and once i did so i am unable to login as it says the pwd is wrong and when i try to reset the pwd it says both my regd mobile num and email id are incorrect ridiculous app update it was working just fine before i was forced to update
# topic is: ['updat', 'app', 'login']
# reasons are: ['reset', 'incorrect']
#
# finger sensor doesnt work on vivo v pro
# topic is: []
# reasons are: []
#
# im really frustrated with this app i v reset the password for once with confirmation email and message but still i cant login in or sign in feeling like to close the account i want to be fix
# topic is: ['app', 'login', 'account']
# reasons are: ['frustrat', 'reset']
#
# worst experience this app is not something that such a huge brand should have in their pocket please change your engineering teamitt services
# topic is: ['app']
# reasons are: ['worst experience', 'chang', 'servic']
#
# i had applied debit card from app  days a go yet i didnt got the card
# topic is: ['debit card', 'app']
# reasons are: []
#
# opened the account long back but agent dont come for verificationi keep scheduling the dates and message from dbs was that agent will call in next hrs forget  hrsits going to be  months and still agent dont call pathetic service by dbs
# topic is: ['account']
# reasons are: ['servic']
#
# worst app there is no response from bank very bad customer care service
# topic is: ['app', 'customer care']
# reasons are: ['bad', 'servic']
#
# worst of the worst application update
# topic is: ['updat']
# reasons are: []
#
# i submitted my request regrading complete my kyc for mutual funds but still not completed and my friend completed his kyc for mutual funds online
# topic is: ['kyc']
# reasons are: []
#
# its working bad
# topic is: []
# reasons are: ['bad']
#
# app does not allow to access any thing just stucks to one page  please resolve the problem
# topic is: ['app']
# reasons are: ['problem']
#
# bekar app its too heavy
# topic is: ['app']
# reasons are: []
#
# this app is not open it showing something went wrong please try again with secure network after that it automatically closes the app please do something about it urgently
# topic is: ['app']
# reasons are: ['open', 'something went wrong']
#
# issue with payment and many other stuff are not responding
# topic is: []
# reasons are: []
#
# adding funds using debit cards is not possible now
# topic is: ['debit cards']
# reasons are: []
#
# it is not letting me open a digisavings account i get an error something went wrong after i input my pan number
# topic is: ['account']
# reasons are: ['open', 'something went wrong']
#
# worse app i am trying to forget username but app can not work
# topic is: ['app']
# reasons are: []
#
# very poor service customer service is not upto the mark they wont help in resolving the issue my account has been frozen since a week  all ekycaadhar card linking is done yesterday customer care support guy told it will be unfreeze in  hrs but till not it has not been done
# topic is: ['customer service', 'account', 'customer care']
# reasons are: ['servic']
#
# very unstable app back button not working when i want to close the app and again and again it asking for my upi id generation plz fix it
# topic is: ['app', 'upi']
# reasons are: ['unstabl', 'not working', 'fix it']
#
# babut hi raddhi app h kuch response hi nahi deta h
# topic is: ['app']
# reasons are: []
#
# add back add from debit card option
# topic is: ['debit card']
# reasons are: []
#
# i have to register frequently on my realme  when i try to login after some time it ask me to register
# topic is: ['login']
# reasons are: []
#
# i felt bad as u removed fund with debit card option if u can add this i will keep my account or els i will close my account with this bank
# topic is: ['debit card', 'account']
# reasons are: ['bad']
#
# adding money from debit card removed it is very use full  please check and add in next update so meny people are not having upi  even paytm having adding funds from debit card than why you people are removed
# topic is: ['debit card', 'updat', 'upi']
# reasons are: []
#
# hell with the app cant even signup to the app tried many times and even received dublicate otps which are not working
# topic is: ['app', 'signup']
# reasons are: ['not working']
#
# number of time  not nothing to login
# topic is: ['login']
# reasons are: []
#
# worst very slow i didnt load money from my payzapp account worst updated version
# topic is: ['account', 'version']
# reasons are: []
#
# high space occupied
# topic is: []
# reasons are: []
#
# biometric verification store visit options very few agent verification scheduled but agents do not come no customer service number open kotak  experience quite smooth
# topic is: ['biometr', 'customer service']
# reasons are: ['servic', 'open']
#
# i didnt get my debit card
# topic is: ['debit card']
# reasons are: []
#
# also shows error
# topic is: []
# reasons are: []
#
# i cant be able to add money into my digi bank savings account when i tried to add money from another bank accounts it always says invalid upi please help
# topic is: ['account', 'another bank', 'upi']
# reasons are: []
#
# not good
# topic is: []
# reasons are: []
#
# what is the use of this bank its app is not working from last  hours i am trying to login but every time it shows sorry we are sad u go how should i feel that this bank is safe thanks i didnt deposit any amount otherwise i would have been stucked in emergency
# topic is: ['app', 'login']
# reasons are: ['not working', 'every time']
#
# i cant do any transaction from last  days and cant withdrawal money using this bank atm
# topic is: ['atm']
# reasons are: []
#
# there is no live support executive only virtual assistant is there to help and it ask only one question
# topic is: []
# reasons are: []
#
# i am using this as my default bank but dbs app ui is worst it lags its slowest and has lot of bugs also my frnds with iphones unable to use this app from last  year suppprt is also worst do something
# topic is: ['app']
# reasons are: []
#
# hello dbs i have savings account in sbi bank my aadhar number and pan linked to sbi account i want new savings account in this paperless bank is it possible
# topic is: ['account']
# reasons are: []
#
# why is your app slow and buggy need faster performance like phonepe
# topic is: ['app']
# reasons are: ['buggi']
#
# now a days its working too slow
# topic is: []
# reasons are: []
#
# what update version is tis not working tis app kindly do neatly
# topic is: ['updat', 'version', 'app']
# reasons are: ['not working']
#
# after creating the account i get a popup saying identity verrified now get ur paywave card i can neither get that popup out nor can i press next which says error
# topic is: ['account']
# reasons are: ['popup']
#
# every time i m open the app it ask for upi id
# topic is: ['app', 'upi']
# reasons are: ['every time', 'open']
#
# worst banking app everytime decline transaction
# topic is: ['app']
# reasons are: []
#
#  ad says open account in  sec but it took me  sec to fill my date of birth need to click every month to go beyond   i wanted to open savings account but while entering aadhar its asking me to accept to move the dbt direct benefits transfer to dbs without that it is not allowing me to open savings account some time before same thing was done by airtel and i know people who are still crying for that this need to an option to select valuntarily should not be a mendatory one first a new bank should gain trust of people now i am uninstalling this app
# topic is: ['account', 'app']
# reasons are: ['open', 'transfer']
#
# the app is stuck at upi generation even after generation of one it would again ask to register after reopen app please fix this because this hasnt been fixed from a long time and i am cant use my account
# topic is: ['app', 'upi', 'account']
# reasons are: ['stuck']
#
# very very slow ui from last week it is crashing left and right after updating to latest version i submitted the crash report to dbs days back still waiting for response from dbs team finally uninstalled the app making use of internet banking
# topic is: ['version', 'app', 'internet']
# reasons are: ['crash']
#
# after login in it is continuesly prompting me to create vpa for upi transaction i have created it once successfully but still after login in its prompting me to create vpa for upi transactions and that popup also cannot be closed i am unable to get into the app due to the popup i have created two vpa due to this popup please lookinto it cant do anything
# topic is: ['login', 'upi', 'app']
# reasons are: ['popup', 'close']
#
# app not showing my account no and ifsc no showing technical issue cant add money cant add pan no cant understand how to make savings account
# topic is: ['app', 'account', 'ifsc']
# reasons are: []
#
# i was getting free atm service for  year now i am not getting it digibank also started to take service charge for atm transaction so now there is no difference between other banks so now digibank savings accounts are useless for me
# topic is: ['atm', 'charg']
# reasons are: ['servic']
#
# everytime we use the upi feature we have to enter the login password we think they should introduce  digit pin feature asap
# topic is: ['upi', 'login']
# reasons are: []
#
# worst experience  my account has been closed abruptly without any warning or information i have used it hrs ago and after that i received mail of closing the account
# topic is: ['account']
# reasons are: ['worst experience', 'close']
#
# worst app cant register and not processing username and password
# topic is: ['app']
# reasons are: []
#
# app is very slow and im cant login
# topic is: ['app', 'login']
# reasons are: []
#
# cant add money of my friends debit card and now this app same paytm
# topic is: ['debit card', 'app']
# reasons are: []
#
# this app doesnt allow me to save my pin the save the pin is greyed out help me
# topic is: ['app']
# reasons are: []
#
# please dont open account in this bluddy bank guys they steal your money  i have dont seen such a poor service and customer care is waste and they wont solve the issues from this bank i lost my money
# topic is: ['account', 'customer care']
# reasons are: ['open', 'servic']
#
# in this app i dont see the option of activate your physical debit card and i got physical debit card so it not use full to me
# topic is: ['app', 'debit card']
# reasons are: []
#
# the app isnt allowing to open the menu and sticks to the lets go page and even after cancelling the lets go page the app isnt responding truly a messy appnot even liked a little bit
# topic is: ['app']
# reasons are: ['open']
#
# i cant reset my password and username  the app stuck please help me devoloper please help me
# topic is: ['app']
# reasons are: ['reset', 'stuck']
#
# every time transfer problems and refund will come after  days very tough to use this account
# topic is: ['account']
# reasons are: ['every time', 'transfer']
#
# i have installed this app for my friend ayaan qureshi and now i am trying this for me you guys are not allowing me to open an new account what a ridiculous app it ths
# topic is: ['app', 'account']
# reasons are: ['open']
#
# sir it is not verifying my number even otp is correct
# topic is: []
# reasons are: []
#
# it is as slow as turtle even though you g net
# topic is: []
# reasons are: []
#
# slow working
# topic is: []
# reasons are: []
#
# the main problem is with app is that it hangs a lot
# topic is: ['app']
# reasons are: ['problem']
#
# they stopped my account suddenly n blocked my money with them m very disappointed with the service
# topic is: ['account']
# reasons are: ['stop', 'servic']
#
# again the same problem of loging in started cant login
# topic is: ['login']
# reasons are: ['problem']
#
# not show personal loan option
# topic is: []
# reasons are: []
#
# ok
# topic is: []
# reasons are: []
#
# fake app  password does not set
# topic is: ['app']
# reasons are: []
#
# it was all fine till the last update now i cant use the app without it crashing all the time even when im not using it
# topic is: ['updat', 'app']
# reasons are: ['crash']
#
# updated review for god sake please fix this issue still cant use my fingerprint to login old review in vivo nex i am cant login via finger print when i touch the area where i need to touch then it goes back to app to enter password this was not the case earlier dunno what went wrong
# topic is: ['login', 'app']
# reasons are: []
#
# app is very slow n laggy improve it asap
# topic is: ['app']
# reasons are: []
#
# i am using same device but why it is asking new device registration for every update
# topic is: ['updat']
# reasons are: []
#
# this app ui is so bad if we compare it with other payment banks like paytm please improve it
# topic is: ['app']
# reasons are: ['bad']
#
# too much take storage  it would be only  to  megabytes
# topic is: []
# reasons are: []
#
# crashing after udate
# topic is: []
# reasons are: ['crash']
#
# it is useless if its branch is not present in your residing towncity
# topic is: []
# reasons are: []
#
# automatically stopped itnot ok
# topic is: []
# reasons are: ['stop']
#
# this upgrade is not letting me open it
# topic is: []
# reasons are: ['open']
#
# the worst banking app i ever used its frequently logout and asking for relogin
# topic is: ['app']
# reasons are: []
#
# after updating dbs app the all buttons showing plainly without name and am unable login worst app i have seen in banking sector kindly select good company for developing app
# topic is: ['app', 'login']
# reasons are: []
#
# not useful app time waste
# topic is: ['app']
# reasons are: []
#
# freezes your account without any intimation
# topic is: ['account']
# reasons are: []
#
# its really frustrating no on call supports my app asking for enabling vpa again and again tried to get help from support they have many numbers but every number seems to have same ivr enabled no executive support on the call just worthless
# topic is: ['app']
# reasons are: ['frustrat']
#
# add money wallet not work
# topic is: []
# reasons are: []
#
# no help bed sarvis
# topic is: []
# reasons are: []
#
# very worst app after i logout and close it then always says app stopped working
# topic is: ['app']
# reasons are: ['stop']
#
# add option to add money from debit card or credit card
# topic is: ['debit card']
# reasons are: []
#
# too slow
# topic is: []
# reasons are: []
#
# something went wrong error
# topic is: []
# reasons are: ['something went wrong']
#
# repeatedly asking for upi registration even after registering for upi doesnt allow to skip need to register for new upi everytime i need to use this app ended up having  upi ids
# topic is: ['upi', 'app']
# reasons are: []
#
# thank you for stopping collection of data
# topic is: []
# reasons are: []
#
# what a poor service from dbsi trans money from dbs to my other bank money got debited from dbs account but deposited to my other bank account its fraud
# topic is: ['account']
# reasons are: ['servic']
#
# the verification by otp does not work so whats the point its a marketing gimmick that open an account online seamlessly
# topic is: ['account']
# reasons are: ['open']
#
# i dont like itit wasnt capable of creating new account with username and password
# topic is: ['account']
# reasons are: []
#
# i am cant load balance to my account it says that your account is inactive and i dont know where to find the customer care
# topic is: ['balanc', 'account', 'customer care']
# reasons are: ['inact']
#
# they cant connect to upi and always says cant be connected try again later
# topic is: ['upi']
# reasons are: []
#
# this app is irritating me as i have to register everyday for my device it automatically logs me off everyday please fix repeatedly registration of device everytime
# topic is: ['app']
# reasons are: []
#
# i wish to invest in mutual funds through dbs  now when i go to mutual funds section it takes me to verify kyc and then takes request online it says it will be completed in  days  fact is its more than  days and still its just taking request from me and nothing has been done  also its so so difficult to connect to customer care is it that we can dont speak to a natural person in dbs finding customer care no is also a big challenge hope real person is reading and replying and its not virtual assistant again which does not give satisfactory reply most of the time
# topic is: ['kyc', 'customer care']
# reasons are: []
#
# pathetic banking services which i came across i am already using citi bank as my primary bank and its the best rather safest bank not like dbs which is the worst bank
# topic is: []
# reasons are: ['servic', 'worst bank']
#
# it was the worst experience everi tried to take ot cash from atm using debit card but it was showing that the pin is incorrect nowi tried to change the pin from the app but every time on the last stepit pops up the message oopssomething went wrongplease try again later it did not came to work when i needed it the most
# topic is: ['atm', 'debit card', 'app']
# reasons are: ['worst experience', 'incorrect', 'chang', 'every time']
#
# application is vry slowm vry disappointed with this application  bankthey are not provide any kind of passbook  check book
# topic is: []
# reasons are: []
#
# i tried changing my upi address as well  but still the issue is same
# topic is: ['upi']
# reasons are: []
#
# the last update was a third class update i can cant login my account
# topic is: ['updat', 'login', 'account']
# reasons are: []
#
# previous app was excellent not happy with latest app
# topic is: ['app']
# reasons are: []
#
# i am facing the problem with upi i have created two vpa but this app is asking me to create again and again please look into this matter
# topic is: ['upi', 'app', 'look']
# reasons are: ['face', 'problem']
#
# add fund debit card option not available we need this option
# topic is: ['debit card']
# reasons are: []
#
# correct password but still cant login
# topic is: ['login']
# reasons are: []
#
# after updating my mobile no i cannot link other bank it says cannot register my mobile no pls solve it
# topic is: []
# reasons are: []
#
# now it is not good
# topic is: []
# reasons are: []
#
# i tried transfer amount to my account its not working
# topic is: ['account']
# reasons are: ['transfer', 'not working']
#
# pathetici have downloading and removing ur app for long timewen i don want ur paywave debit cardwhy r u forcing me on appas such ur network in india is bad
# topic is: ['app']
# reasons are: ['forc', 'bad']
#
# ur competition is gonna kill youimprove ur app response speed
# topic is: ['app', 'speed']
# reasons are: []
#
# unable to login through correct login id and password also
# topic is: ['login']
# reasons are: []
#
# very very very bad this apps
# topic is: []
# reasons are: ['bad']
#
# i have updated my adhar card with the corrected spelling of my name on st feb  fingerprint verify done mail the adhar card to your digi ambassador done but its still doesnt reflect my correct name on my account all you say is bank instantly no need to go to bank i have talked to your customer care several times mailed your agent in physical branch in pune several times still no use account open using fingerprint verify otp takes  minsthen why does updating adhar using same takes  days really digibank ur service is pathetic i am closing my account
# topic is: ['account', 'customer care']
# reasons are: ['reflect', 'open', 'servic']
#
# i unable to login my account after the updating its happened very bad app
# topic is: ['login', 'account', 'app']
# reasons are: ['bad']
#
# i am cant login to my account for last  days with this app neither with fingerprint nor with password an error page comes up please check this and resolve as soon as possible
# topic is: ['login', 'account', 'app']
# reasons are: []
#
# this is cimplitly bogus app its hang the phone on login
# topic is: ['app', 'login']
# reasons are: []
#
# guys its service is very worst i have been using this account suddenly they freeze my account without reasons telling it is under investigation at least they are unable to tell the reason and tat period when it is going to solve thank god i was planning to do fd of  lakhs not yet done or else i should be wondering around its branches at least solve my problem account is freezed
# topic is: ['account']
# reasons are: ['servic', 'problem']
#
# when i login to my account popup tells identification done now get your visa paywave debit card when i proceed and fill in the details it says digibank only select cities and there is no way to cancel all this i am cant use my account x button to close the popup doesnt work please fix it edit you must be from  locations where they a branch they wont mention it
# topic is: ['login', 'account', 'debit card']
# reasons are: ['popup', 'fix it']
#
# enable add money options through debit card
# topic is: ['debit card']
# reasons are: []
#
# not working properly many times showing something went to wrong try to again please improve this app
# topic is: ['app']
# reasons are: ['not working']
#
# unable to login generate unexpected error
# topic is: ['login']
# reasons are: []
#
# very pathetic service they automatically blocked my account and after that i applied for closure the account my account has been closed but the remaining balance does not credited to my respective account even i tried alot to talk with the customer service team but i was unable to do so i called even i mailed but no response i will dont recommend this bank
# topic is: ['account', 'balanc', 'customer service']
# reasons are: ['servic', 'close']
#
# first the app used to crash when adding a nominee after a couple days it worked then i received the debit card and tried to activate it the activate button didnt get enabled after entering pin in two boxes the in the reenter pin box i erased and retyped the last digit and it was enabled the app looks very unstable and unreliable im an android developer myself and i can confirm such issues are a result of very little testing and quality assurance cannot use this as my primary account as its unreliable
# topic is: ['app', 'debit card', 'account']
# reasons are: ['unstabl']
#
# i set vpa at least  or  times but it still ask to create vpavery bad experience
# topic is: []
# reasons are: ['bad']
#
# facing trouble in logincontacted customer care no reply
# topic is: ['customer care']
# reasons are: ['face']
#
# this app is uselessdont open account in dbsmy personal suggestion i open my account on  nov but till today i am unable to use my account due to some technical problemi registered complaint on same daycustomer excutives tell me that it will take  days to solve this problemvery bad service by dbs because  days longer time period for this little issue
# topic is: ['app', 'account']
# reasons are: ['open', 'bad', 'servic']
#
# i am cant login app from last  days dont wht issue is persisting fed up
# topic is: ['login', 'app']
# reasons are: []
#
# cant loginhelp meits urgent
# topic is: []
# reasons are: []
#
# new app is worst not working your consent enable us to serve you betterthis notice does not go by either options yes im in or skip for now remove the new app then again update old app
# topic is: ['app', 'updat']
# reasons are: ['not working']
#
# even after numerous emails to dbs bank still they are not delivereing the monthly statement directly to customer email address one need to download from the app manually
# topic is: ['app']
# reasons are: []
#
# not goodstops working
# topic is: []
# reasons are: []
#
# the popup of debit card is not cancelled by clicking cross button so the account is not showing in app
# topic is: ['debit card', 'account', 'app']
# reasons are: ['popup']
#
# not working properly
# topic is: []
# reasons are: ['not working']
#
# i am using digi bank from last  year but now i am getting problem to withdraw cash using debit card its showing your transaction is not permitted i didnt get any customer service helpline where i can resolve my problem please revert me back asp
# topic is: ['debit card', 'customer service']
# reasons are: ['problem', 'servic']
#
# my location not delivered my debit card but show shipping address add this option please solve this problem
# topic is: ['debit card']
# reasons are: ['problem']
#
# crashes after vpa transfer
# topic is: []
# reasons are: ['crash', 'transfer']
#
# no branch in a city deprives fingerprint authmtication at least a small store or a tieup should be available across major cities for people to complete the mandatory proesses
# topic is: []
# reasons are: []
#
# bakwas banki have tried to withdraw  from atm the transaction was failedbut amount deductedstill not get the money
# topic is: ['atm']
# reasons are: []
#
# devit card delivery proplem
# topic is: []
# reasons are: []
#
# pls dbs add option for money add by debit card
# topic is: ['debit card']
# reasons are: []
#
# app is not at all working after update no characters are visible
# topic is: ['app', 'updat']
# reasons are: []
#
# too many charges  to have funds credited it charges  as service charge  worst customer support  kotak  icici digital accounts are far better than this
# topic is: ['charg']
# reasons are: ['servic']
#
# i have not changed the device but within  days it made me to confirm the device login by  times
# topic is: ['login']
# reasons are: []
#
# cant activate my debit card  it takes me to enter pin and then activation part is faded out and also changing email  now i am frustrated
# topic is: ['debit card']
# reasons are: ['frustrat']
#
# my statement show balance but not show in app please solve my problem
# topic is: ['balanc', 'app']
# reasons are: ['problem']
#
# the app is slow the inbuilt ai support digbot is not very helpful and the bank doesnt have proper timely human customer support
# topic is: ['app']
# reasons are: []
#
# main pichley  november ko digibank app seh e wallet account open ki request kiya tha magar mera account abhitak open nai hua customer care pe complaint kiya magar abhitak koi response nai aye very bad experience
# topic is: ['app', 'account', 'customer care']
# reasons are: ['open', 'bad']
#
# i am unable to login and it shows error try with secured network what is happening i love this bank but not anymore please make sure that you meet all the expectations of customers
# topic is: ['login']
# reasons are: []
#
# app crashes whedont i try to login says try login into secure network i have been using the same network i need to make the transaction immediately please assist
# topic is: ['app', 'login']
# reasons are: ['crash']
#
# very slow
# topic is: []
# reasons are: []
#
# lots of time i was trying to contact customer care executive but they are not receivedcall me
# topic is: ['customer care']
# reasons are: []
#
# the app functioned great until quite recently on a pixel  the app keeps running in the background and crashes happens  times on a daily basis
# topic is: ['app']
# reasons are: ['crash']
#
# even when i am using latest versioni am getting message like we have detected you are using old version i think there is some issue with your detection system
# topic is: ['version']
# reasons are: []
#
# app is really slow to use interface must be smooth and fast please resolve this issue as early as possible need to register after every update this is not a good thing
# topic is: ['app', 'updat']
# reasons are: []
#
# there was an option to add money using debit card which is not available now will it be available in the next update i can see the other options to add money but i was looking to add money via debit card also there comes a popup frequently stating the application has crashed
# topic is: ['debit card', 'updat']
# reasons are: ['popup', 'crash']
#
# always giving error while open of the stable app
# topic is: ['app']
# reasons are: ['open']
#
# i am cant login plzhelp
# topic is: ['login']
# reasons are: []
#
# this app needs to follow india internet banking apps like sbi axis etc no support we cannot expect from them if something went wrong with payment
# topic is: ['app', 'internet']
# reasons are: ['something went wrong']
#
# when i login to my account a page popup tells identification is done now get your physical debit card when i proceed and fill the details it say digi bank only available in selected city i stuck in these  pages cant use my account
# topic is: ['login', 'account', 'debit card']
# reasons are: ['popup', 'stuck']
# what the hell is wrong with your app guys  when ever i am trying to login its taking m device as a new device and again i need to go with registration process after that it blocks my transactions for  hours and again the same scenario next time is there anyone who can look into this or you people are not testing your app before releasing
# topic is: ['app', 'login', 'look']
# reasons are: []
#
# i didnt see any facilities
# topic is: []
# reasons are: []
#
# when ever im trying to open the app its showing something went wrongplease try with a secure networkso i wnt to request the dbs team to look after ths matter asap
# topic is: ['app', 'look']
# reasons are: ['open']
#
# can you please roll back the functionality for add money by card
# topic is: []
# reasons are: []
#
# manu customer service number and mail id
# topic is: ['customer service']
# reasons are: ['servic']
#
# now a days it is always asking to continue with the same old mobile number or update new mobile numberi have kept the old mobile numberbut it is asking again and again whedont i open the app
# topic is: ['updat', 'app']
# reasons are: ['open']
#
# cant use app bcoz of more not working screens
# topic is: ['app']
# reasons are: ['not working']
#
# i have done kyc but still cant deposit money pls check and confirm
# topic is: ['kyc']
# reasons are: []
#
# i am unable to login my account from the app its not showing any text buttons and when i put my user id and password and press on the blank button the process symbol comes and the app doesnt move forward i have been using this app for over a year please solve this issue immediately as a have to do transactions from my bank account
# topic is: ['login', 'account', 'app']
# reasons are: []
#
# digibanking app is too slow wont help in weak network area we dont have option to break the fd and rd wherever we have urgent need of money
# topic is: ['app']
# reasons are: []
#
# completed the kyc but unable to load cash into the account dont know what i am missing
# topic is: ['kyc', 'account']
# reasons are: []
#
# im unable to login even after resetting my password so many times
# topic is: ['login']
# reasons are: ['reset']
#
# app show server time out unable to connect
# topic is: ['app']
# reasons are: []
#
# i have updated the app now its not possible to add money from debit card give me solution
# topic is: ['app', 'debit card']
# reasons are: []
#
# after updating app is not working properly
# topic is: ['app']
# reasons are: ['not working']
#
# i am cant login to my bank
# topic is: ['login']
# reasons are: []
#
# often says server is busy during aadhar otp verification process for the past one monthfed up with thatand no use
# topic is: []
# reasons are: []
#
# this is not connecting in google pay
# topic is: []
# reasons are: []
#
# why i can not disable visa paywave this feature is fraud prone and why no costumer helpline
# topic is: []
# reasons are: []
#
# i am make a transaction th december but the amount debited from my dbs account or dont received my beneficiary my amount are not refunded
# topic is: ['account']
# reasons are: []
#
# tried to transfer money through app money got deducted from my account but receiver didnt receive money tried calling on all available numbera of dbs no nunber is working i need money immediately back
# topic is: ['app', 'account']
# reasons are: ['transfer', 'deduct']
#
# please add option add money from debit card
# topic is: ['debit card']
# reasons are: []
#
# this bank is oll indan is a not saport help mai and bank is oll over indan is opens
# topic is: []
# reasons are: []
#
# sir please upload a correct information of biometric verification in digibank app
# topic is: ['biometr', 'app']
# reasons are: []
#
# good app but after update this app is crashing always please look after this
# topic is: ['app', 'updat', 'look']
# reasons are: ['crash']
#
# i have activated vpa for my account but whedont i am going to login it redirects me to upi creation page automatically and there is no way to come back to home i cant even do anything with the app useless
# topic is: ['account', 'login', 'upi', 'app']
# reasons are: []
#
# easiest way to open a bank account but app needs a lot of improvements and speed very very slow and unresponsive now
# topic is: ['account', 'app', 'speed']
# reasons are: ['open']
#
# unexpected error  i cant update my account nominee it through me out of this app
# topic is: ['updat', 'account', 'app']
# reasons are: []
#
# this size should be less than mb
# topic is: []
# reasons are: []
#
# app doesnt work i have already reset ur password but it is again asking to reset the password not login into ac worst update and not identifying fingerprint also
# topic is: ['app', 'login', 'updat']
# reasons are: ['reset']
#
# everything was good but now app is hanging so much plz improve your app asap improve yourself before making my mind up
# topic is: ['app']
# reasons are: []
#
# this application is very slow
# topic is: []
# reasons are: []
#
# slow working damd app
# topic is: ['app']
# reasons are: []
#
# the app is disgusting it asks me to create a upi address after every mins irrespective of my existing upi address in addition to that it cannot be brought back to the home page of the app
# topic is: ['app', 'upi']
# reasons are: []
#
# when i try to signup it says your information already exists when i try to login it says your account cant be found so net net cant use the app
# topic is: ['signup', 'login', 'account', 'app']
# reasons are: []
#
# latest update issue im unable to login its loading for sometime and showing error
# topic is: ['updat', 'login']
# reasons are: []
#
# it always automatically stops
# topic is: []
# reasons are: ['stop']
#
# after your new update it keeps hanging cant be able to proceed old version was so cool  please fix it
# topic is: ['updat', 'version']
# reasons are: ['fix it']
#
# app is too damn slow worst ui ever
# topic is: ['app']
# reasons are: []
#
# bad application worst experience pls resolve this big bug for this
# topic is: []
# reasons are: ['bad', 'worst experience']
#
# after the new update app is not working please fix the bugs in it
# topic is: ['updat', 'app']
# reasons are: ['not working']
#
# i am trying to activate dbs debit card but while setting pin save pin button is not getting enabled
# topic is: ['debit card']
# reasons are: []
#
# still facing login issue till last update  dec  app interface is not smooth or attractive
# topic is: ['login', 'updat', 'app']
# reasons are: ['face']
#
# everything was fine but with an update now it is not possible to add money from any atm cards
# topic is: ['updat', 'atm']
# reasons are: []
#
# im still facing the same issue  just after the recent update the app started behaving abnormal every time i try to login the phone gets shut down and restart for a while until i shutdown the phone and force reboot it did not stop so i had to uninstall this app
# topic is: ['updat', 'app', 'login']
# reasons are: ['face', 'every time', 'forc', 'stop']
#
# unable to contact customer care for any complaints or clarification so difficult to contact to bank
# topic is: ['customer care']
# reasons are: []
#
# there is no debit card option for adding money please implement this option
# topic is: ['debit card']
# reasons are: []
#
# i have updated app it always popup the notifications tat dbs india unfortunately stopped working could you please resolve this issue
# topic is: ['app']
# reasons are: ['popup', 'stop']
#
# the dbs bank apps ask us our consent to collect dataon the name of more serviceswhich if i says skip for now the corrupt application takes you to next page kn which it asks are you sure to proceed without consentbut the consent tabs yes or no not showing to you fully so if one clicks right tab he is giving consent to access and left one he still is giving access maybe
# topic is: []
# reasons are: []
#
# i dont want the debit card for nowbut yet the screen comes up and even when i try to close itit doesnt closei just cant explore the app and be confident of what i have installedplease help me with this issue thanks
# topic is: ['debit card', 'app']
# reasons are: ['screen']
#
# only this app using amount transactions onlybut now that particular facilities remove the new versionso i need required old version visa card to payment get options
# topic is: ['app', 'version']
# reasons are: []
#
# didnt received debit card tracking number till now nor debit card
# topic is: ['debit card']
# reasons are: []
#
# the customer care is useless i have few queries but there is no way i could speak to the customer care executive the toll free number doesnt support answering queries
# topic is: ['customer care']
# reasons are: []
#
# i already have upi yet the updated version asking to register for upi and so i cant use the app at all no other way there i have to close the app i have one query too is there any debit card charges
# topic is: ['upi', 'version', 'app', 'debit card']
# reasons are: []

# %%
from sNetworkx import SNetworkx
snetworkx = SNetworkx()
t = sutility.getFamousTopics()[0]
r = sutility.getReasonDict()[0]
print('topic:', t)
print('reasons', r[1])
snetworkx.inputData(t, r[1])
snetworkx.show()
# Out:
# topic: ('app', 142)
# reasons [('open', 19), ('bad', 13), ('not working', 12), ('reset', 7), ('crash', 7), ('every time', 6), ('chang', 6), ('popup', 5), ('worst experience', 5), ('servic', 5), ('unstabl', 4), ('stuck', 4), ('problem', 4), ('face', 4), ('fix it', 4), ('frustrat', 4), ('stop', 3), ('something went wrong', 3), ('screen', 3), ('incorrect', 3), ('forc', 2), ('suck', 2), ('transfer', 2), ('buggi', 1), ('close', 1), ('deduct', 1), ('reflect', 1), ('deposit', 1), ('broke', 1)]
# /home/nawaz/.virtualenvs/AWSComp/lib/python3.5/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
sutility.showTopicCounts()
print('---------------------------------')
sutility.showReasonDict()
# Out:
# [('app', 142), ('account', 58), ('login', 53), ('debit card', 39), ('updat', 38), ('upi', 25), ('customer care', 12), ('version', 11), ('atm', 8), ('kyc', 7), ('customer service', 7), ('look', 5), ('biometr', 4), ('balanc', 4), ('signup', 3), ('internet', 2), ('ifsc', 2), ('debit cards', 2), ('charg', 2), ('speed', 2), ('offer', 1), (None, 1), ('back option', 1), ('postal code', 1), ('deals and offers', 1), ('another bank', 1), ('international transactions', 1)]
# ---------------------------------
# app
# [('open', 19), ('bad', 13), ('not working', 12), ('reset', 7), ('crash', 7), ('every time', 6), ('chang', 6), ('popup', 5), ('worst experience', 5), ('servic', 5), ('unstabl', 4), ('stuck', 4), ('problem', 4), ('face', 4), ('fix it', 4), ('frustrat', 4), ('stop', 3), ('something went wrong', 3), ('screen', 3), ('incorrect', 3), ('forc', 2), ('suck', 2), ('transfer', 2), ('buggi', 1), ('close', 1), ('deduct', 1), ('reflect', 1), ('deposit', 1), ('broke', 1)]
#
# account
# [('open', 14), ('servic', 10), ('transfer', 7), ('bad', 6), ('popup', 4), ('chang', 3), ('close', 2), ('stuck', 2), ('deduct', 2), ('reset', 2), ('problem', 2), ('inact', 2), ('fix it', 2), ('every time', 2), ('screen', 2), ('not working', 2), ('frustrat', 2), ('unstabl', 1), ('wrong', 1), ('add amount', 1), ('something went wrong', 1), ('worst experience', 1), ('deposit', 1), ('forc', 1), ('dormant', 1), ('stop', 1), ('reflect', 1)]
#
# login
# [('reset', 7), ('popup', 4), ('stuck', 4), ('face', 4), ('every time', 3), ('problem', 3), ('fix it', 2), ('worst experience', 2), ('bad', 2), ('incorrect', 2), ('chang', 2), ('crash', 1), ('forc', 1), ('close', 1), ('servic', 1), ('something went wrong', 1), ('server issue', 1), ('not working', 1), ('frustrat', 1), ('open', 1), ('stop', 1)]
#
# debit card
# [('popup', 4), ('worst experience', 3), ('servic', 2), ('problem', 2), ('stuck', 2), ('unstabl', 1), ('crash', 1), ('fix it', 1), ('every time', 1), ('transfer', 1), ('screen', 1), ('frustrat', 1), ('bad', 1), ('incorrect', 1), ('chang', 1)]
#
# updat
# [('popup', 4), ('not working', 4), ('crash', 4), ('open', 3), ('every time', 2), ('reset', 2), ('face', 2), ('worst experience', 2), ('chang', 2), ('buggi', 1), ('forc', 1), ('fix it', 1), ('bad', 1), ('suck', 1), ('stop', 1), ('broke', 1), ('incorrect', 1)]
#
# upi
# [('every time', 3), ('problem', 3), ('not fixed', 1), ('unstabl', 1), ('popup', 1), ('fix it', 1), ('add amount', 1), ('close', 1), ('transfer', 1), ('screen', 1), ('stuck', 1), ('inact', 1), ('not working', 1), ('frustrat', 1), ('open', 1), ('face', 1)]
#
# customer care
# [('servic', 4), ('open', 3), ('bad', 2), ('reflect', 1), ('reset', 1), ('inact', 1), ('face', 1)]
#
# version
# [('not working', 1), ('open', 1), ('crash', 1), ('fix it', 1), ('suck', 1)]
#
# atm
# [('chang', 2), ('transfer', 1), ('forc', 1), ('dormant', 1), ('every time', 1), ('worst experience', 1), ('servic', 1), ('incorrect', 1)]
#
# kyc
# [('open', 1), ('popup', 1)]
#
# customer service
# [('servic', 7), ('worst experience', 1), ('open', 1), ('close', 1), ('problem', 1)]
#
# look
# [('crash', 1), ('problem', 1), ('suck', 1), ('not working', 1), ('open', 1), ('face', 1), ('chang', 1)]
#
# biometr
# [('open', 2), ('bad', 1), ('servic', 1)]
#
# balanc
# [('problem', 1), ('close', 1), ('servic', 1), ('inact', 1)]
#
# signup
# [('reflect', 1), ('not working', 1), ('contact details', 1)]
#
# internet
# [('crash', 1), ('something went wrong', 1)]
#
# ifsc
# [('reflect', 1), ('open', 1)]
#
# debit cards
# [('suck', 1)]
#
# charg
# [('servic', 2)]
#
# speed
# [('open', 1)]
#
# offer
# []
#
# None
# [('bad', 1)]
#
# back option
# [('not working', 1), ('suck', 1), ('chang', 1)]
#
# postal code
# [('forc', 1), ('chang', 1)]
#
# deals and offers
# []
#
# another bank
# []
#
# international transactions
# []

# %%
# from IPython.core.display import display, HTML
# # display(HTML('<h1>Hello, world!</h1>'))
# HTML(filename='g.html')
# from PIL import Image                                                                                
# img = Image.open('/home/nawaz/PycharmProjects/SentimentAnalysis/graphDemo.png')
# img.show() 

from IPython.display import Image

Image(filename = "/home/nawaz/PycharmProjects/SentimentAnalysis/graphDemo.png", width=500, height=500)

# %%
# sutility.showTopicCounts()
# sentList = commentsDocument.map()
# sentList = commentsDocument.map(getSentiment)

# %%
# from sGraph import *
# new1()
# makeHistogram()
# makeGraph()

# %%
l = list(commentsDocument)
p = list(processed_doc)

length = len(l)

for i in range(length):
    print(l[i])
    print(p[i])
    print()

# %%
# dump = list(zip(commentsDocument, processed_doc))
# length = len(dump)
# for i in range(length):
#     print(dump[i][0])
#     print(dump[i][1])
# #     print(sentList.iloc[i])
#     print()

# %%
import gensim
dictionary = gensim.corpora.Dictionary(processed_doc)
# dictionary.filter_extremes(no_below=5, no_above=0.5, keep_n=100000)
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_doc]

# %%
from gensim import corpora, models
corpus_tfidf = models.TfidfModel(bow_corpus)[bow_corpus]

# %%
lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics=5, id2word=dictionary, passes=2, workers=2)

# %%
# indexFor = 5
# print('..COMMENT :', commentsDocument[indexFor])
# print('\n..CORPOS :', processed_doc[indexFor])
# # print('\n..BOW:', bow_corpus[indexFor])
# for index, score in sorted(lda_model_tfidf[bow_corpus[indexFor]], key=lambda tup: -1*tup[1]):
#     print("\nScore: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 5)))

# %%
topics = lda_model_tfidf.print_topics(num_words=4)
for topic in topics:
    print(topic)

# %%
# print(processed_doc.values)

# %%
l = tokenDictWithPosNegSentiment(list(sentList), list(processed_doc))

# %%
# print(sortedMostPos(l))

# %%
from showBarGraph import *
# show positive bar graph
showBarCharForSentiment(sortedMostPos(l), pos=True)

# %%
# print(sortedMostNeg(l))
# show positive bar graph
showBarCharForSentiment(sortedMostNeg(l), pos=False)

# %%
showPiChart(sortedMostFreq(l))

# %%
# showTempBarChart()

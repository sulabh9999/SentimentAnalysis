# %%
import time
from bs4 import BeautifulSoup
import sys, io
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.proxy import *


product = 'com.dbs.in.digitalbank'
driver = webdriver.Firefox(executable_path='/usr/local/bin/geckodriver')
timeOut = 30 # seconds

# driver.set_page_load_timeout(timeOut)
# wait = WebDriverWait( driver, timeOut)
driver.implicitly_wait(timeOut) 
url = 'https://play.google.com/store/apps/details?id=' + product + '&hl=en_IN&showAllReviews=true'
driver.get(url)
page = driver.page_source
soup_expatistan = BeautifulSoup(page, "html.parser")

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
downloads = soup_expatistan.find('span', {'class': 'AYi5wd'}) 
print('Total comments are: ', downloads.text)
 
ratingDiv = soup_expatistan.find('div', {'class': 'pf5lIe'}) 

import re
text = str(ratingDiv.get_text)
try:
    found = re.search('Rated(.+?)stars out of five stars', text).group(1).strip()
except AttributeError:
    found = 'None' 
print('Raitings: ', found)
# Out:
# Total comments are:  79,921
# Raitings:  4.1

# %%
# expatistan_table = soup_expatistan.find("h1", class_="AHFaub")
# print(expatistan_table.string)

# %%
# no_of_reviews = 1000
# ratings = soup_expatistan.find("span", class_="EymY4b")
# print(ratings.text)

# %%
# SCROLL_PAUSE_TIME = 2.0

# # Get scroll height
# last_height = driver.execute_script("return document.body.scrollHeight")
# count=0

# while True:
#     # Scroll down to bottom
#     driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

#     # Wait to load page
#     time.sleep(SCROLL_PAUSE_TIME)

#     # Calculate new scroll height and compare with last scroll height
# #     new_height = driver.execute_script("return document.body.scrollHeight")
#     if count == 4:
#         try:
#             show = driver.find_element_by_class_name('PFAhAf')
#             show.click()
#             count = 0
#         except NoSuchElementException:
#             print('got exception ', NoSuchElementException)
#     else:
#         count = count + 1

# %%
from selenium.common.exceptions import NoSuchElementException, WebDriverException, TimeoutException
from IPython.display import display, clear_output



requiredComments = 15000

count = 0
totalComments = 200
while totalComments < requiredComments:
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#     driver.execute_script("window.scrollTo(0, -10000);")
    
    if count >= 4:
        try:
            show = driver.find_element_by_class_name('PFAhAf')
            show.click()
            totalComments = totalComments + 160
            count = 0
        except NoSuchElementException:
            print('got exception ', NoSuchElementException)
    else:
        count = count + 1

    time.sleep(1)
    
#     clear_output(wait=True)
    print('Fetched comments: %d/%d' %(totalComments, requiredComments))
# Out:
# Fetched comments: 200/15000
# Fetched comments: 200/15000
# Fetched comments: 200/15000
# Fetched comments: 200/15000
# got exception  <class 'selenium.common.exceptions.NoSuchElementException'>
# Fetched comments: 200/15000
# Fetched comments: 360/15000
# Fetched comments: 360/15000
# Fetched comments: 360/15000
# Fetched comments: 360/15000
# Fetched comments: 360/15000
# Fetched comments: 520/15000
# Fetched comments: 520/15000
# Fetched comments: 520/15000
# Fetched comments: 520/15000
# Fetched comments: 520/15000
# Fetched comments: 680/15000
# Fetched comments: 680/15000
# Fetched comments: 680/15000
# Fetched comments: 680/15000
# Fetched comments: 680/15000
# Fetched comments: 840/15000
# Fetched comments: 840/15000
# Fetched comments: 840/15000
# Fetched comments: 840/15000
# Fetched comments: 840/15000
# Fetched comments: 1000/15000
# Fetched comments: 1000/15000
# Fetched comments: 1000/15000
# Fetched comments: 1000/15000
# Fetched comments: 1000/15000
# Fetched comments: 1160/15000
# Fetched comments: 1160/15000
# Fetched comments: 1160/15000
# Fetched comments: 1160/15000
# Fetched comments: 1160/15000
# Fetched comments: 1320/15000
# Fetched comments: 1320/15000
# Fetched comments: 1320/15000
# Fetched comments: 1320/15000
# Fetched comments: 1320/15000
# Fetched comments: 1480/15000
# Fetched comments: 1480/15000
# Fetched comments: 1480/15000
# Fetched comments: 1480/15000
# Fetched comments: 1480/15000
# Fetched comments: 1640/15000
# Fetched comments: 1640/15000
# Fetched comments: 1640/15000
# Fetched comments: 1640/15000
# Fetched comments: 1640/15000
# Fetched comments: 1800/15000
# Fetched comments: 1800/15000
# Fetched comments: 1800/15000
# Fetched comments: 1800/15000
# Fetched comments: 1800/15000
# Fetched comments: 1960/15000
# Fetched comments: 1960/15000
# Fetched comments: 1960/15000
# Fetched comments: 1960/15000
# Fetched comments: 1960/15000
# Fetched comments: 2120/15000
# Fetched comments: 2120/15000
# Fetched comments: 2120/15000
# Fetched comments: 2120/15000
# Fetched comments: 2120/15000
# Fetched comments: 2280/15000
# Fetched comments: 2280/15000
# Fetched comments: 2280/15000
# Fetched comments: 2280/15000
# Fetched comments: 2280/15000
# Fetched comments: 2440/15000
# Fetched comments: 2440/15000
# Fetched comments: 2440/15000
# Fetched comments: 2440/15000
# Fetched comments: 2440/15000
# Fetched comments: 2600/15000
# Fetched comments: 2600/15000
# Fetched comments: 2600/15000
# Fetched comments: 2600/15000
# Fetched comments: 2600/15000
# Fetched comments: 2760/15000
# Fetched comments: 2760/15000
# Fetched comments: 2760/15000
# Fetched comments: 2760/15000
# Fetched comments: 2760/15000
# Fetched comments: 2920/15000
# Fetched comments: 2920/15000
# Fetched comments: 2920/15000
# Fetched comments: 2920/15000
# Fetched comments: 2920/15000
# Fetched comments: 3080/15000
# Fetched comments: 3080/15000
# Fetched comments: 3080/15000
# Fetched comments: 3080/15000
# Fetched comments: 3080/15000
# Fetched comments: 3240/15000
# Fetched comments: 3240/15000
# Fetched comments: 3240/15000
# Fetched comments: 3240/15000
# Fetched comments: 3240/15000
# Fetched comments: 3400/15000
# Fetched comments: 3400/15000
# Fetched comments: 3400/15000
# Fetched comments: 3400/15000
# Fetched comments: 3400/15000
# Fetched comments: 3560/15000
# Fetched comments: 3560/15000
# Fetched comments: 3560/15000
# Fetched comments: 3560/15000
# Fetched comments: 3560/15000
# Fetched comments: 3720/15000
# Fetched comments: 3720/15000
# Fetched comments: 3720/15000
# Fetched comments: 3720/15000
# Fetched comments: 3720/15000
# Fetched comments: 3880/15000
# Fetched comments: 3880/15000
# Fetched comments: 3880/15000
# Fetched comments: 3880/15000
# Fetched comments: 3880/15000
# Fetched comments: 4040/15000
# Fetched comments: 4040/15000
# Fetched comments: 4040/15000
# Fetched comments: 4040/15000
# Fetched comments: 4040/15000
# Fetched comments: 4200/15000
# Fetched comments: 4200/15000
# Fetched comments: 4200/15000
# Fetched comments: 4200/15000
# Fetched comments: 4200/15000
# Fetched comments: 4360/15000
# Fetched comments: 4360/15000
# Fetched comments: 4360/15000
# Fetched comments: 4360/15000
# Fetched comments: 4360/15000
# Fetched comments: 4520/15000
# Fetched comments: 4520/15000
# Fetched comments: 4520/15000
# Fetched comments: 4520/15000
# Fetched comments: 4520/15000
# Fetched comments: 4680/15000
# Fetched comments: 4680/15000
# Fetched comments: 4680/15000
# Fetched comments: 4680/15000
# Fetched comments: 4680/15000
# Fetched comments: 4840/15000
# Fetched comments: 4840/15000
# Fetched comments: 4840/15000
# Fetched comments: 4840/15000
# Fetched comments: 4840/15000
# Fetched comments: 5000/15000
# Fetched comments: 5000/15000
# Fetched comments: 5000/15000
# Fetched comments: 5000/15000
# Fetched comments: 5000/15000
# Fetched comments: 5160/15000
# Fetched comments: 5160/15000
# Fetched comments: 5160/15000
# Fetched comments: 5160/15000
# Fetched comments: 5160/15000
# Fetched comments: 5320/15000
# Fetched comments: 5320/15000
# Fetched comments: 5320/15000
# Fetched comments: 5320/15000
# Fetched comments: 5320/15000
# Fetched comments: 5480/15000
# Fetched comments: 5480/15000
# Fetched comments: 5480/15000
# Fetched comments: 5480/15000
# Fetched comments: 5480/15000
# Fetched comments: 5640/15000
# Fetched comments: 5640/15000
# Fetched comments: 5640/15000
# Fetched comments: 5640/15000
# Fetched comments: 5640/15000
# Fetched comments: 5800/15000
# Fetched comments: 5800/15000
# Fetched comments: 5800/15000
# Fetched comments: 5800/15000
# Fetched comments: 5800/15000
# Fetched comments: 5960/15000
# Fetched comments: 5960/15000
# Fetched comments: 5960/15000
# Fetched comments: 5960/15000
# Fetched comments: 5960/15000
# Fetched comments: 6120/15000
# Fetched comments: 6120/15000
# Fetched comments: 6120/15000
# Fetched comments: 6120/15000
# Fetched comments: 6120/15000
# Fetched comments: 6280/15000
# Fetched comments: 6280/15000
# Fetched comments: 6280/15000
# Fetched comments: 6280/15000
# Fetched comments: 6280/15000
# Fetched comments: 6440/15000
# Fetched comments: 6440/15000
# Fetched comments: 6440/15000
# Fetched comments: 6440/15000
# Fetched comments: 6440/15000
# Fetched comments: 6600/15000
# Fetched comments: 6600/15000
# Fetched comments: 6600/15000
# Fetched comments: 6600/15000
# Fetched comments: 6600/15000
# Fetched comments: 6760/15000
# Fetched comments: 6760/15000
# Fetched comments: 6760/15000
# Fetched comments: 6760/15000
# Fetched comments: 6760/15000
# Fetched comments: 6920/15000
# Fetched comments: 6920/15000
# Fetched comments: 6920/15000
# Fetched comments: 6920/15000
# Fetched comments: 6920/15000
# Fetched comments: 7080/15000
# Fetched comments: 7080/15000
# Fetched comments: 7080/15000
# Fetched comments: 7080/15000
# Fetched comments: 7080/15000
# Fetched comments: 7240/15000
# Fetched comments: 7240/15000
# Fetched comments: 7240/15000
# Fetched comments: 7240/15000
# Fetched comments: 7240/15000
# Fetched comments: 7400/15000
# Fetched comments: 7400/15000
# Fetched comments: 7400/15000
# Fetched comments: 7400/15000
# Fetched comments: 7400/15000
# Fetched comments: 7560/15000
# Fetched comments: 7560/15000
# Fetched comments: 7560/15000
# Fetched comments: 7560/15000
# Fetched comments: 7560/15000
# Fetched comments: 7720/15000
# Fetched comments: 7720/15000
# Fetched comments: 7720/15000
# Fetched comments: 7720/15000
# Fetched comments: 7720/15000
# Fetched comments: 7880/15000
# Fetched comments: 7880/15000
# Fetched comments: 7880/15000
# Fetched comments: 7880/15000
# Fetched comments: 7880/15000
# Fetched comments: 8040/15000
# Fetched comments: 8040/15000
# Fetched comments: 8040/15000
# Fetched comments: 8040/15000
# Fetched comments: 8040/15000
# Fetched comments: 8200/15000
# Fetched comments: 8200/15000
# Fetched comments: 8200/15000
# Fetched comments: 8200/15000
# Fetched comments: 8200/15000
# Fetched comments: 8360/15000
# Fetched comments: 8360/15000
# Fetched comments: 8360/15000
# Fetched comments: 8360/15000
# Fetched comments: 8360/15000
# Fetched comments: 8520/15000
# Fetched comments: 8520/15000
# Fetched comments: 8520/15000
# Fetched comments: 8520/15000
# Fetched comments: 8520/15000
# Fetched comments: 8680/15000
# Fetched comments: 8680/15000
# Fetched comments: 8680/15000
# Fetched comments: 8680/15000
# Fetched comments: 8680/15000
# Fetched comments: 8840/15000
# Fetched comments: 8840/15000
# Fetched comments: 8840/15000
# Fetched comments: 8840/15000
# Fetched comments: 8840/15000
# Fetched comments: 9000/15000
# Fetched comments: 9000/15000
# Fetched comments: 9000/15000
# Fetched comments: 9000/15000
# Fetched comments: 9000/15000
# Fetched comments: 9160/15000
# Fetched comments: 9160/15000
# Fetched comments: 9160/15000
# Fetched comments: 9160/15000
# Fetched comments: 9160/15000
# Fetched comments: 9320/15000
# Fetched comments: 9320/15000
# Fetched comments: 9320/15000
# Fetched comments: 9320/15000
# Fetched comments: 9320/15000
# Fetched comments: 9480/15000
# Fetched comments: 9480/15000
# Fetched comments: 9480/15000
# Fetched comments: 9480/15000
# Fetched comments: 9480/15000
# Fetched comments: 9640/15000
# Fetched comments: 9640/15000
# Fetched comments: 9640/15000
# Fetched comments: 9640/15000
# Fetched comments: 9640/15000
# Fetched comments: 9800/15000
# Fetched comments: 9800/15000
# Fetched comments: 9800/15000
# Fetched comments: 9800/15000
# Fetched comments: 9800/15000
# Fetched comments: 9960/15000
# Fetched comments: 9960/15000
# Fetched comments: 9960/15000
# Fetched comments: 9960/15000
# Fetched comments: 9960/15000
# Fetched comments: 10120/15000
# Fetched comments: 10120/15000
# Fetched comments: 10120/15000
# Fetched comments: 10120/15000
# Fetched comments: 10120/15000
# Fetched comments: 10280/15000
# Fetched comments: 10280/15000
# Fetched comments: 10280/15000
# Fetched comments: 10280/15000
# Fetched comments: 10280/15000
# Fetched comments: 10440/15000
# Fetched comments: 10440/15000
# Fetched comments: 10440/15000
# Fetched comments: 10440/15000
# Fetched comments: 10440/15000
# Fetched comments: 10600/15000
# Fetched comments: 10600/15000
# Fetched comments: 10600/15000
# Fetched comments: 10600/15000
# Fetched comments: 10600/15000
# Fetched comments: 10760/15000
# Fetched comments: 10760/15000
# Fetched comments: 10760/15000
# Fetched comments: 10760/15000
# Fetched comments: 10760/15000
# Fetched comments: 10920/15000
# Fetched comments: 10920/15000
# Fetched comments: 10920/15000
# Fetched comments: 10920/15000
# Fetched comments: 10920/15000
# Fetched comments: 11080/15000
# Fetched comments: 11080/15000
# Fetched comments: 11080/15000
# Fetched comments: 11080/15000
# Fetched comments: 11080/15000
# Fetched comments: 11240/15000
# Fetched comments: 11240/15000
# Fetched comments: 11240/15000
# Fetched comments: 11240/15000
# Fetched comments: 11240/15000
# Fetched comments: 11400/15000
# Fetched comments: 11400/15000
# Fetched comments: 11400/15000
# Fetched comments: 11400/15000
# Fetched comments: 11400/15000
# got exception  <class 'selenium.common.exceptions.NoSuchElementException'>
# Fetched comments: 11400/15000
# Fetched comments: 11560/15000
# Fetched comments: 11560/15000
# Fetched comments: 11560/15000
# Fetched comments: 11560/15000
# Fetched comments: 11560/15000
# Fetched comments: 11720/15000
# Fetched comments: 11720/15000
# Fetched comments: 11720/15000
# Fetched comments: 11720/15000
# Fetched comments: 11720/15000
# Fetched comments: 11880/15000
# Fetched comments: 11880/15000
# Fetched comments: 11880/15000
# Fetched comments: 11880/15000
# Fetched comments: 11880/15000
# Fetched comments: 12040/15000
# Fetched comments: 12040/15000
# Fetched comments: 12040/15000
# Fetched comments: 12040/15000
# Fetched comments: 12040/15000
# Fetched comments: 12200/15000
# Fetched comments: 12200/15000
# Fetched comments: 12200/15000
# Fetched comments: 12200/15000
# Fetched comments: 12200/15000
# Fetched comments: 12360/15000
# Fetched comments: 12360/15000
# Fetched comments: 12360/15000
# Fetched comments: 12360/15000
# Fetched comments: 12360/15000
# Fetched comments: 12520/15000
# Fetched comments: 12520/15000
# Fetched comments: 12520/15000
# Fetched comments: 12520/15000
# Fetched comments: 12520/15000
# Fetched comments: 12680/15000
# Fetched comments: 12680/15000
# Fetched comments: 12680/15000
# Fetched comments: 12680/15000
# Fetched comments: 12680/15000
# Fetched comments: 12840/15000
# Fetched comments: 12840/15000
# Fetched comments: 12840/15000
# Fetched comments: 12840/15000
# Fetched comments: 12840/15000
# Fetched comments: 13000/15000
# Fetched comments: 13000/15000
# Fetched comments: 13000/15000
# Fetched comments: 13000/15000
# Fetched comments: 13000/15000
# Fetched comments: 13160/15000
# Fetched comments: 13160/15000
# Fetched comments: 13160/15000
# Fetched comments: 13160/15000
# Fetched comments: 13160/15000
# Fetched comments: 13320/15000
# Fetched comments: 13320/15000
# Fetched comments: 13320/15000
# Fetched comments: 13320/15000
# Fetched comments: 13320/15000
# Fetched comments: 13480/15000
# Fetched comments: 13480/15000
# Fetched comments: 13480/15000
# Fetched comments: 13480/15000
# Fetched comments: 13480/15000
# Fetched comments: 13640/15000
# Fetched comments: 13640/15000
# Fetched comments: 13640/15000
# Fetched comments: 13640/15000
# Fetched comments: 13640/15000
# Fetched comments: 13800/15000
# Fetched comments: 13800/15000
# Fetched comments: 13800/15000
# Fetched comments: 13800/15000
# Fetched comments: 13800/15000
# Fetched comments: 13960/15000
# Fetched comments: 13960/15000
# Fetched comments: 13960/15000
# Fetched comments: 13960/15000
# Fetched comments: 13960/15000
# Fetched comments: 14120/15000
# Fetched comments: 14120/15000
# Fetched comments: 14120/15000
# Fetched comments: 14120/15000
# Fetched comments: 14120/15000
# Fetched comments: 14280/15000
# Fetched comments: 14280/15000
# Fetched comments: 14280/15000
# Fetched comments: 14280/15000
# Fetched comments: 14280/15000
# got exception  <class 'selenium.common.exceptions.NoSuchElementException'>
# Fetched comments: 14280/15000
# Fetched comments: 14440/15000
# Fetched comments: 14440/15000
# Fetched comments: 14440/15000
# Fetched comments: 14440/15000
# Fetched comments: 14440/15000
# Fetched comments: 14600/15000
# Fetched comments: 14600/15000
# Fetched comments: 14600/15000
# Fetched comments: 14600/15000
# Fetched comments: 14600/15000
# Fetched comments: 14760/15000
# Fetched comments: 14760/15000
# Fetched comments: 14760/15000
# Fetched comments: 14760/15000
# Fetched comments: 14760/15000
# Fetched comments: 14920/15000
# Fetched comments: 14920/15000
# Fetched comments: 14920/15000
# Fetched comments: 14920/15000
# Fetched comments: 14920/15000
# Fetched comments: 15080/15000

# %%
print('Trying to extract comments from driver, please wait for sometime...')

xpath = "/html/body/div[1]/div[5]/c-wiz/div/div[2]/div/div[1]/div/div/div[1]/div[2]"
div = driver.find_element_by_xpath(xpath).get_attribute("innerHTML")
soup = BeautifulSoup(div, 'html.parser')
allCommentDiv = soup.find("div", {"jsname": "fk8dgd"}).find_all("div", {"jscontroller": "H6eOGe"})

print('total comments are: ', len(allCommentDiv))

info = []
count = 0
for each in allCommentDiv:
    name = each.find('span', {'class': 'X43Kjb'})
    ratings = len(each.find_all('div', {'class': 'vQHuPe'}))
    date = each.find('span', {'class': 'p2TkOb'})
    comment = each.find('span', {'jsname': 'bN97Pc'})
    fillComment =  each.find('span', {'jsname': 'fbQN7e'})
    if len(fillComment.text) > 0 :
        comment = fillComment
        
    clear_output(wait=True)
    display('Total extrated comments are: ' + str(count))
    count = count + 1
#     print('name: ', name.text)
#     print('rating: ', ratings)
#     print('date: ', date.text)
#     print('comment: ', comment.text)
    result = [name.text, date.text, comment.text, ratings]
    info.append(result)
    
reverseList = reversed(info)
# Out:
# 'Total extrated comments are: 15079'

# %%
print(len(info))
print(info[720])
# Out:
# 15080
# ['AKHILESH SHARMA', '18 April 2019', 'ok', 5]

# %%
backup = info

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(data=np.array(info), columns=['name', 'date', 'comment', 'rating'])
fileNameToStore = 'android_comments_jan_24April2019.pkl'
df.to_pickle(fileNameToStore)
b = pd.read_pickle(fileNameToStore)

# %%
import pandas as pd
import numpy as np
from py.SDataSource import *
import os

path = os.getcwd()
oldComment = 'android_commens_till_27_02_19.pkl'
newComment = 'dgIndia_android_29Feb19_07April19.pkl'

# %%
old_df = pd.read_pickle(oldComment)
new_df = pd.read_pickle(newComment)
start = '01-01-2019'
end = '21-04-2019'

# %%
old_comments = getListOfCommentsFromPkl([start, end], oldComment)
new_comments = getListOfCommentsFromPkl([start, end], newComment)

# %%
# merged_df = pd.concat([old_df, new_df], sort=True)
# merged_df = pd.merge(old_df, new_df, on='datetime')

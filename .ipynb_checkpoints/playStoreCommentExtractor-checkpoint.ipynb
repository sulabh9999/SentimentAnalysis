# %%
import time
from bs4 import BeautifulSoup
import sys, io
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.proxy import *


product = 'com.dbs.in.digitalbank'
driver = webdriver.Firefox(executable_path='/usr/local/bin/geckodriver')

# wait = WebDriverWait( driver, 10)
url = 'https://play.google.com/store/apps/details?id=' + product + '&hl=en_IN&showAllReviews=true'
driver.get(url)
page = driver.page_source
soup_expatistan = BeautifulSoup(page, "html.parser")

# %load_ext autoreload
# %autoreload 2

# %%
downloads = soup_expatistan.find('span', {'class': 'AYi5wd'}) 
print(downloads.text)

ratingDiv = soup_expatistan.find('div', {'class': 'pf5lIe'}) 

import re
text = str(ratingDiv.get_text)
try:
    found = re.search('Rated(.+?)stars out of five stars', text).group(1).strip()
except AttributeError:
    found = 'None' 
print(found)
# Out:
# 69,780
# 4.0

# %%
# expatistan_table = soup_expatistan.find("h1", class_="AHFaub")
# print(expatistan_table.string)

# %%
# no_of_reviews = 1000
# ratings = soup_expatistan.find("span", class_="EymY4b")
# print(ratings.text)

# %%
# d1 = soup_expatistan.find("div", {"jsname": "fk8dgd"})
# print(d1)

# %%
from selenium.common.exceptions import NoSuchElementException

totalComments = 20

while totalComments > 0:
     # Action scroll down
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    try:
        show = driver.find_element_by_class_name('PFAhAf')
        show.click()
    except NoSuchElementException:
        pass
    
    totalComments = totalComments - 40
    time.sleep(2)

# %%
xpath = "/html/body/div[1]/div[4]/c-wiz/div/div[2]/div/div[1]/div/div/div[1]/div[2]"
div = driver.find_element_by_xpath(xpath).get_attribute("innerHTML")
soup = BeautifulSoup(div, 'html.parser')
allCommentDiv = soup.find("div", {"jsname": "fk8dgd"}).find_all("div", {"jscontroller": "H6eOGe"})
print('total comments are: ', len(allCommentDiv))

info = []
for each in allCommentDiv:
    name = each.find('span', {'class': 'X43Kjb'})
    ratings = len(each.find_all('div', {'class': 'vQHuPe'}))
    date = each.find('span', {'class': 'p2TkOb'})
    comment = each.find('span', {'jsname': 'bN97Pc'})
    fillComment =  each.find('span', {'jsname': 'fbQN7e'})
    if len(fillComment.text) > 0 :
        comment = fillComment
    
    print('name: ', name.text)
    print('rating: ', ratings)
    print('date: ', date.text)
    print('comment: ', comment.text)
    result = [name.text, date.text, comment.text, ratings]
    info.append(result)
    print('-----------------------------------')
# Out:
# total comments are:  80
# name:  A Google user
# rating:  1
# date:  24 February 2019
# comment:  I don't understand,how I contact to the Bank , I reset my phone and than they ask me for OTP 1st time I enter wrong than 2nd time I enter carefully right OTP and than 3rd time also. Now from 2 weeks my account gives error account is temprory locked and where and whom should I contact I don't understand , please help me
# -----------------------------------
# name:  Siva Reddy
# rating:  4
# date:  24 February 2019
# comment:  Thank you so much for your immediate and best solution on the issue and shorted out with in one day. Very very happy with the service good banking experience. 😄😆
# -----------------------------------
# name:  lokesh jangde
# rating:  5
# date:  24 February 2019
# comment:  Amazing app. Yet the app is little bit slow but features of dbs are so awesome that i no longer use any other bank apps.
# -----------------------------------
# name:  Ashoo Sachan
# rating:  5
# date:  24 February 2019
# comment:  Hi My Name is Anand Prakash.I Am using DigiBank Services From Last 1 And Half Year.I want Say just One Word Its Awsome..!!!
# -----------------------------------
# name:  Rajiv Pandey
# rating:  4
# date:  24 February 2019
# comment:  Very smooth and easy to use interface.
# -----------------------------------
# name:  Hamid Shaikh
# rating:  5
# date:  24 February 2019
# comment:  nice bank
# -----------------------------------
# name:  suddhashil mukhuty
# rating:  5
# date:  24 February 2019
# comment:  very good
# -----------------------------------
# name:  Hemant Desai
# rating:  4
# date:  16 February 2019
# comment:  This rating is purely for the app and not bank and the services provided. Loved the simple, sort of minimalist approach and yet provide some very essential important features. The higher level of comfort knowing that the security used is a class of it's own. However, this experience can go a long way if the bank were to offer more service and integrate it into the app.
# -----------------------------------
# name:  Vishal Rex
# rating:  1
# date:  17 February 2019
# comment:  I have my dbs account which I cant login. I enter my username & password and then it asks me otp. After entering the otp correctly it says linking device... device linking failed and then I'm logged out. I had opened by dbs wallet last year on my same phone. Now when I'm trying to convert it to savings account for months, it shows the same error every time. I cant even create a fresh account on my phone as it shows the error that this devive is already linked with another account.
# -----------------------------------
# name:  Aeshar Manzar
# rating:  2
# date:  24 February 2019
# comment:  Hey DBS, you can make your Mobile App better like other mobile banking app ex Kotak Bank App. Your android mobile app is so slow and not smooth. It is got hanged every time i open the app. Make it smoother.
# -----------------------------------
# name:  Aniket Jagtap
# rating:  1
# date:  20 February 2019
# comment:  this app has issue with PAN varification and there issue resolved system is too much dump,cant trust this bank who dont care there customer.....I had very worst experince with this bank,suggest to go for other banks. dear dbs,stop giving us feedback link in comment.shame on you,customer have to post compliant in app store that show how your system capable of.go and do your work
# -----------------------------------
# name:  Madhu Badisha
# rating:  1
# date:  18 February 2019
# comment:  you have been saying that "we are coming soon in Hyderabad" for a long time now. if I dont get my KYC done by 2nd March, my account will be frozen I almost lost faith in your statements. Good bye👎
# -----------------------------------
# name:  Devesh Rastogi
# rating:  2
# date:  24 February 2019
# comment:  It keeps registering the same device every few days as a new one. Send SMS again and again. Customer care had assured that it's a technical issue and will be sorted out soon. had been working for past one month. But it has started again. Have to register the device again each time I try to login. Very frustrating. wastes time and does not allow txns for 24 hrs each time the phone is re-registered.
# -----------------------------------
# name:  Krishna Chaitanya Cherukuri
# rating:  3
# date:  16 February 2019
# comment:  Good Concept, been using it for more than a year now. The inbuilt security breaks whenever there is an update, so need to reinstall. It is almost impossible to get in touch with support for issues other than the predefined FAQ. Unable to complete MF KYC and no option to contact support or report the issue. Update - 16 Feb 2019 After using more than a year and frequent updates issues have been resolved and the app works without any issues. Keep up the good work team.
# -----------------------------------
# name:  kiran nookala
# rating:  1
# date:  21 February 2019
# comment:  lost my mobile and do not hold my mobile linked with the app ,sent a mail to customer care to update my new mobile number and no response till now . unfortunately forgot my app password as I did not ise it for many montgs as using a UPI app for quote some time . email response is less ...virtual assistant is useless no customer care no works .even 1* is too much. sent a mail ..no response ...they wanted me to go to tge nearest branch in person and get it done and nearest bank brach is 700 kms .
# -----------------------------------
# name:  Sudhir Gosavi
# rating:  3
# date:  22 February 2019
# comment:  i am happy with the simplicity of this app. But i have been told that there is personal loan facility in the same app where we can see how much personal loan we are eligible.i am not able to find that section in my app, as it is my salary account do there any other app from digi bank for this facility.
# -----------------------------------
# name:  Kiran kumar k
# rating:  1
# date:  16 February 2019
# comment:  worst app.. can't able to log in..updates are essential for any app.. but frequent updates with a span of 7 days is worst.. more over it wont let to login unless we update.. Dear bank.. please listen to customer issues.. build apps for the users atleast to log in.. forget about enhancements..
# -----------------------------------
# name:  Rahul singh
# rating:  5
# date:  21 February 2019
# comment:  This new version ask again abd again to login in sams Phone.Below msgs comes up.... You tried accessing digibank via a new device on 21-02-2019 at 23:43. Please log into digibank and contact us via DIGI Virtual Assistant to report any suspected fraud. please correct this bug.
# -----------------------------------
# name:  Sayan Dutta
# rating:  1
# date:  24 February 2019
# comment:  now it is really annoying that every time i went to login and it is saying you are try to login from differemt device so otp is needed and mobile sms sent everytime and deducts 1.50 from my sim card.. tell me one thing are you guys stupid,i use same mobile but same thing repeated again and again
# -----------------------------------
# name:  Shankar G
# rating:  1
# date:  19 February 2019
# comment:  why there is no response regarding digibucks email.. i need to know how to add auto bill pay for mutual fund which i created in digibank app? what i need to do when i would like to speak to customer care? no options available.. pls call me!
# -----------------------------------
# name:  risabh sharma
# rating:  1
# date:  23 February 2019
# comment:  Isnt there any other way to open a savings account without the biometric scan.Due to an accident my fingerprints are not scanable through any machine.I called digibank's support team,seems like they are clueless about this.Can you guys help me with this. Thanks.
# -----------------------------------
# name:  Prantik Sarkar
# rating:  5
# date:  23 February 2019
# comment:  The security is up to standard..the developers need to keep on improving platform integration with better User Interface on the basis of User experience..especially for users who are not tech savvy providing guide and awareness for the masses will make this one of the best microfinance banking..good going
# -----------------------------------
# name:  Shashank Sathe
# rating:  5
# date:  19 February 2019
# comment:  Application shows runtime system error and quits... Sad to see that the release is not tested for H2OS and Android handsets running custom ROMs too 👎👎 Addendum: Seems to be working pretty well now. Am liking the app 😃
# -----------------------------------
# name:  Kaushik Das
# rating:  5
# date:  16 February 2019
# comment:  I am really in love with this bank, it was so easy to open the account no hastle at all zero balance savings account was opened all sitting at home. ATM card was sent to my address within 7 days of accout activation. For the biometric verification their representative will visit the address which you fill in online form while opening the account. I have opened a RD account and this bank is giving me 7.5% interest also. I also got Rs 500 as cashback for two successful referrals. Thank you DBS.
# -----------------------------------
# name:  Sivakumar Gobi
# rating:  1
# date:  19 February 2019
# comment:  my app is not opening right now.. only a blank screen while opening digibank app.. pathetic app... fix this bug asap
# -----------------------------------
# name:  Rahul Pandey
# rating:  5
# date:  24 February 2019
# comment:  One of the best bank in india, can't imagine a bank can provide this much facilities...thanks a lot, if you also collaborate with e-commerce sites then it would be beneficial 🙂
# -----------------------------------
# name:  PkiraN PaTIL
# rating:  5
# date:  19 February 2019
# comment:  nice eazy application gr8 banking service loved it! suggestions to application developer kindly add recharge options easy way rechargeable from contact not to easy taking time please fix the bug @@@@
# -----------------------------------
# name:  Vaibhav Dodake
# rating:  5
# date:  17 February 2019
# comment:  This bank is comfortable more than we expect. It has so amazing facilities. This bank is my favorite bank and i have opened not only my account but also i have referred all family members and they have also joined with this bank. Loved it ♥️👍🏻
# -----------------------------------
# name:  Sandeep Kumar
# rating:  1
# date:  16 February 2019
# comment:  i forgot my user id and password iam past three monts to reset user id and password but it shows every time something went wrong please try again what is issue when you solve this problem plese provide your custmer care number
# -----------------------------------
# name:  Raajkumar R
# rating:  5
# date:  18 February 2019
# comment:  I'm signing up with the App. I've created an account but not able to proceed to account activities without applying for a debit card. I don't want a debit card as of now. How can I skip this?
# -----------------------------------
# name:  Proceph
# rating:  4
# date:  16 February 2019
# comment:  The app is great. Minor hiccups and lags here and there. But please don't be like google and give us the changelogs for the app. Especially since this is a super important app.
# -----------------------------------
# name:  Amiit kumar Das
# rating:  4
# date:  19 February 2019
# comment:  This app is only made for who using maximum nmbr of internet banking or nothing else but need more improvements like axis bank UI And need cheque book also for This saving account
# -----------------------------------
# name:  appaji pt
# rating:  4
# date:  21 February 2019
# comment:  Good Bank and pls put unlimited transaction for atm for some more day.... it will helpfull for the ppl also and for Bank also this what I believe.... Overall it's good they are providing visible Bank experience
# -----------------------------------
# name:  Rohit Kumar Singh
# rating:  1
# date:  18 February 2019
# comment:  worst services.... guys please don't open your account in dbs .. for just bloody cashback.....
# -----------------------------------
# name:  p pang
# rating:  2
# date:  20 February 2019
# comment:  Highly unreliable debit card. POS says "transaction denied by bank". my card isnt blocked and have sufficient balance as well. customer care doesnt work either.
# -----------------------------------
# name:  Ankit Mishra
# rating:  4
# date:  22 February 2019
# comment:  this app and bank is very as we know but when i open my account first app showing to go ccd for verification with address, i went they told service finish . then i called customer care they told need to go to bank , i went bank in nariman poit , they told machine not there for biometric . finally i have book for 11 march . My problem is that why still CCD option coming and why bank is not having machine as they claim to be very big and safest bank .
# -----------------------------------
# name:  Pankaj
# rating:  5
# date:  18 February 2019
# comment:  Awesome bank. It is safest bank. Live unstoppable in digital age. All are smart inside the app. Working well. Only one thing we need to kyc point all over the bihar district. Thanks.
# -----------------------------------
# name:  Praghash K
# rating:  5
# date:  16 February 2019
# comment:  This is one of the most trusted bank compared to other banks in india, even this is a virtual banking its provides better reliability stability and security to the users. Especially this banking application is well designed and provides reqired information. Only one suggestion, please make kyc verification centres all over the districts of Tamilnadu. Overall, a satisfied customer. Thanks team. #மகிழ்ச்சி
# -----------------------------------
# name:  vamsi krishna
# rating:  2
# date:  16 February 2019
# comment:  Have to improve alot on displaying information accurately. For example when you search for a mutual fund irrespective of the search app is showing irrelevant lists of funds.
# -----------------------------------
# name:  Parikshit Kanetkar
# rating:  5
# date:  18 February 2019
# comment:  Since the update from 2 days ago..App gets hanged after transaction and needs to be closed. Pls look in to it.
# -----------------------------------
# name:  prasanna sunil
# rating:  5
# date:  17 February 2019
# comment:  good bank for personal loans it will credited to your account in just 3 to 4 steps with out any paperwork or to call customer care.
# -----------------------------------
# name:  A Google user
# rating:  4
# date:  21 February 2019
# comment:  Digi bank is good service u banking all facility is good . but coustomer service is slow . Very nice from the second bank . Digi bank good. Axise bank is 100% fraud 200% fake .
# -----------------------------------
# name:  Mohan shyle
# rating:  1
# date:  24 February 2019
# comment:  Many times i tried...im not even able to send the mail... your mailbox is full itseems
# -----------------------------------
# name:  NISHU MALHOTRA
# rating:  3
# date:  23 February 2019
# comment:  Please Improving Services . For Example : Fund Transfer by UPI not to be Transfer Any Other UPI Address and Other Technical issues .
# -----------------------------------
# name:  Rose Suneeth
# rating:  5
# date:  17 February 2019
# comment:  Been a customer for about little more than a year, services has been awesome and everything else except I cannot apply for a big basket card..😐😐😐
# -----------------------------------
# name:  A Google user
# rating:  3
# date:  21 February 2019
# comment:  last 2 days my upi trasection is not completed for DBS bank. This bank show me "You are exceted transection for 24 hours".
# -----------------------------------
# name:  Ajay Kolipaka
# rating:  1
# date:  19 February 2019
# comment:  login should be much simplfied, need to improve performance alot.
# -----------------------------------
# name:  A Google user
# rating:  1
# date:  21 February 2019
# comment:  i just started...i cant able to confirm my address.why? and it says without otp fund will be transfer.too bad
# -----------------------------------
# name:  Khokan Sarkar
# rating:  1
# date:  21 February 2019
# comment:  I want to complete my figure print verification in kolkata.So i want to know the holiday list in the month March.
# -----------------------------------
# name:  azhar sayyad
# rating:  4
# date:  22 February 2019
# comment:  The service from bank for new user where up to mark one of the best app for digital bankin.
# -----------------------------------
# name:  Bijay Kumar Shaw
# rating:  3
# date:  16 February 2019
# comment:  Really convenient banking but you should also provide cashback offers for recharges and bill payments made through this app, else it's not so profitable to the customers.
# -----------------------------------
# name:  yesraj films
# rating:  5
# date:  23 February 2019
# comment:  total dhamal mobile Bank app Men's supar frast netbankking Sachin Tendulkar bren,mens Bharat ratno
# -----------------------------------
# name:  Parag Nabar
# rating:  3
# date:  23 February 2019
# comment:  Reasonably good but needs some improvement. Like when choosing Bank branch during transfer, Mumbai shows only one branch fir Axis Bank while there are over 25. Digibot is of no use since the answers are all automated.
# -----------------------------------
# name:  kam trik
# rating:  1
# date:  21 February 2019
# comment:  Verry bad experience with this app becose this is not working in my city Ludhiana, Punjab pin141010. I did not give single star for this hopeless app. This app is not helpful for me.
# -----------------------------------
# name:  Neel bhardwaj
# rating:  5
# date:  17 February 2019
# comment:  I love this bank and its services but it provid service in limited states and city.
# -----------------------------------
# name:  A Google user
# rating:  5
# date:  23 February 2019
# comment:  its really a great app. i suggest all of u to go through this bank. its really believable and they always make their clients happy, its a trustworthy. im using this from one year. and my experience is best with this bank. thanks so much for your service.! 😊
# -----------------------------------
# name:  deepika pal
# rating:  3
# date:  24 February 2019
# comment:  App is slow and not attractive user interface. Pl improve the design and speed
# -----------------------------------
# name:  I. VijaykrTalk
# rating:  5
# date:  17 February 2019
# comment:  amazing app. i have never seen thats type of bank. DBS Bank is really Digital bank. thanks.
# -----------------------------------
# name:  A Google user
# rating:  2
# date:  22 February 2019
# comment:  I forgot my username so i push the forgot username and wait for the OTP but did not receive it and i cant login to my account now. Bad experience ...
# -----------------------------------
# name:  suraj shelke
# rating:  1
# date:  21 February 2019
# comment:  very very bad app , after twice finger print successfull authentication unable to proceed futher and no support at all.
# -----------------------------------
# name:  Pradeep Maurya
# rating:  5
# date:  19 February 2019
# comment:  its awesome app fund transfer is so easy Thankx DBS Bank.
# -----------------------------------
# name:  Deb Kunti
# rating:  1
# date:  16 February 2019
# comment:  After update today's latest version, when I want to login, everytime it ask to register your device. Solve this bugs.
# -----------------------------------
# name:  A Google user
# rating:  5
# date:  20 February 2019
# comment:  superb app I'm so happy that for womens it's a wonderful bank becos it doesn't have any branch thanks alot to DBS bank a new system in this India n in Chennai I just love this Bank...
# -----------------------------------
# name:  Gaurav Verma
# rating:  1
# date:  21 February 2019
# comment:  very slow app. takes lot of time to open. user interface is also very laggy. and many time otp requires for opening the app for no reason.
# -----------------------------------
# name:  Mahboob Anwar
# rating:  1
# date:  23 February 2019
# comment:  Worst experience ever from this bank. Can't login to my account since last 15 days. Can't even find online support for this.
# -----------------------------------
# name:  Shehbaz Qureshi
# rating:  5
# date:  18 February 2019
# comment:  taking Back my negetive words....wanna say one thing.... Best Bank in India!!!!! 😊
# -----------------------------------
# name:  tejas patil
# rating:  1
# date:  21 February 2019
# comment:  all process in complete for debit card but debit card is not received and customer care number is always switch off
# -----------------------------------
# name:  Maverick's Arrow
# rating:  4
# date:  17 February 2019
# comment:  Please update the app, it going slow, while I use it..
# -----------------------------------
# name:  gordon sebastian
# rating:  5
# date:  23 February 2019
# comment:  Used Digibank since its launch .The experience has been nothing short of pleasurable
# -----------------------------------
# name:  librado cupa
# rating:  1
# date:  16 February 2019
# comment:  bad i cannot use online transaction
# -----------------------------------
# name:  Zoom Goswami
# rating:  5
# date:  17 February 2019
# comment:  fast & handy. More than a year I am using this app.
# -----------------------------------
# name:  Narasimha N
# rating:  3
# date:  19 February 2019
# comment:  some glitches are there while paying through upi after getting payment notification.
# -----------------------------------
# name:  Mr. Vishal
# rating:  5
# date:  20 February 2019
# comment:  NICE banking system because it gives unlimited times money transfer, unlimited ATM money withdraw .. GOOD bank I used last 2Year good experience . thankyou digibank
# -----------------------------------
# name:  A Google user
# rating:  5
# date:  16 February 2019
# comment:  Superb app compared to other bank apps. All options available in one app , recharge,bill payment and investment. DBS is excelllllent!!!💎💎💎
# -----------------------------------
# name:  Piyali Piya Das
# rating:  3
# date:  16 February 2019
# comment:  more attractive and easy access like Axis bank app
# -----------------------------------
# name:  Ammu Ds
# rating:  5
# date:  16 February 2019
# comment:  this is good service only please give me personal loan
# -----------------------------------
# name:  Angel Rachna Jitender
# rating:  5
# date:  16 February 2019
# comment:  Awesome Easy and smart with 0 balance maintain account, and i like this too much because i can pay all payments very easily, Thankyou DBS
# -----------------------------------
# name:  A Google user
# rating:  5
# date:  18 February 2019
# comment:  easy to operate and quick to respond ....DBS is a really good option
# -----------------------------------
# name:  Senthil Arumugam N
# rating:  4
# date:  16 February 2019
# comment:  easy to assess, easy transfer, NEED to money transfer to paytm, Google pay, etc
# -----------------------------------
# name:  Maula Shaikh
# rating:  5
# date:  16 February 2019
# comment:  very useful application , best online bank app
# -----------------------------------

# %%
print(len(info))
# Out:
# 80

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(data=np.array(info), columns=['name', 'date', 'comment', 'rating'])

df.to_pickle('android_comment_data.pkl')
b = pd.read_pickle('android_comment_data.pkl')
print(b)
# Out:
#                            name              date  \
# 0                 A Google user  24 February 2019
# 1                    Siva Reddy  24 February 2019
# 2                 lokesh jangde  24 February 2019
# 3                  Ashoo Sachan  24 February 2019
# 4                  Rajiv Pandey  24 February 2019
# 5                  Hamid Shaikh  24 February 2019
# 6            suddhashil mukhuty  24 February 2019
# 7                  Hemant Desai  16 February 2019
# 8                    Vishal Rex  17 February 2019
# 9                 Aeshar Manzar  24 February 2019
# 10                Aniket Jagtap  20 February 2019
# 11                Madhu Badisha  18 February 2019
# 12               Devesh Rastogi  24 February 2019
# 13  Krishna Chaitanya Cherukuri  16 February 2019
# 14                kiran nookala  21 February 2019
# 15                Sudhir Gosavi  22 February 2019
# 16                Kiran kumar k  16 February 2019
# 17                  Rahul singh  21 February 2019
# 18                  Sayan Dutta  24 February 2019
# 19                    Shankar G  19 February 2019
# 20                risabh sharma  23 February 2019
# 21               Prantik Sarkar  23 February 2019
# 22               Shashank Sathe  19 February 2019
# 23                  Kaushik Das  16 February 2019
# 24               Sivakumar Gobi  19 February 2019
# 25                 Rahul Pandey  24 February 2019
# 26                 PkiraN PaTIL  19 February 2019
# 27               Vaibhav Dodake  17 February 2019
# 28                Sandeep Kumar  16 February 2019
# 29                  Raajkumar R  18 February 2019
# ..                          ...               ...
# 50             Bijay Kumar Shaw  16 February 2019
# 51                 yesraj films  23 February 2019
# 52                  Parag Nabar  23 February 2019
# 53                     kam trik  21 February 2019
# 54                Neel bhardwaj  17 February 2019
# 55                A Google user  23 February 2019
# 56                  deepika pal  24 February 2019
# 57               I. VijaykrTalk  17 February 2019
# 58                A Google user  22 February 2019
# 59                 suraj shelke  21 February 2019
# 60               Pradeep Maurya  19 February 2019
# 61                    Deb Kunti  16 February 2019
# 62                A Google user  20 February 2019
# 63                 Gaurav Verma  21 February 2019
# 64                Mahboob Anwar  23 February 2019
# 65              Shehbaz Qureshi  18 February 2019
# 66                  tejas patil  21 February 2019
# 67             Maverick's Arrow  17 February 2019
# 68             gordon sebastian  23 February 2019
# 69                 librado cupa  16 February 2019
# 70                 Zoom Goswami  17 February 2019
# 71                  Narasimha N  19 February 2019
# 72                   Mr. Vishal  20 February 2019
# 73                A Google user  16 February 2019
# 74              Piyali Piya Das  16 February 2019
# 75                      Ammu Ds  16 February 2019
# 76        Angel Rachna Jitender  16 February 2019
# 77                A Google user  18 February 2019
# 78           Senthil Arumugam N  16 February 2019
# 79                 Maula Shaikh  16 February 2019
#
#                                               comment rating
# 0   I don't understand,how I contact to the Bank ,...      1
# 1   Thank you so much for your immediate and best ...      4
# 2   Amazing app. Yet the app is little bit slow bu...      5
# 3   Hi My Name is Anand Prakash.I Am using DigiBan...      5
# 4              Very smooth and easy to use interface.      4
# 5                                           nice bank      5
# 6                                           very good      5
# 7   This rating is purely for the app and not bank...      4
# 8   I have my dbs account which I cant login. I en...      1
# 9   Hey DBS, you can make your Mobile App better l...      2
# 10  this app has issue with PAN varification and t...      1
# 11  you have been saying that "we are coming soon ...      1
# 12  It keeps registering the same device every few...      2
# 13  Good Concept, been using it for more than a ye...      3
# 14  lost my mobile and do not hold my mobile linke...      1
# 15  i am happy with the simplicity of this app. Bu...      3
# 16  worst app.. can't able to log in..updates are ...      1
# 17  This new version ask again abd again to login ...      5
# 18  now it is really annoying that every time i we...      1
# 19  why there is no response regarding digibucks e...      1
# 20  Isnt there any other way to open a savings acc...      1
# 21  The security is up to standard..the developers...      5
# 22  Application shows runtime system error and qui...      5
# 23  I am really in love with this bank, it was so ...      5
# 24  my app is not opening right now.. only a blank...      1
# 25  One of the best bank in india, can't imagine a...      5
# 26  nice eazy application gr8 banking service love...      5
# 27  This bank is comfortable more than we expect. ...      5
# 28  i forgot my user id and password iam past thre...      1
# 29  I'm signing up with the App. I've created an a...      5
# ..                                                ...    ...
# 50  Really convenient banking but you should also ...      3
# 51  total dhamal mobile Bank app Men's supar frast...      5
# 52  Reasonably good but needs some improvement. Li...      3
# 53  Verry bad experience with this app becose this...      1
# 54  I love this bank and its services but it provi...      5
# 55  its really a great app. i suggest all of u to ...      5
# 56  App is slow and not attractive user interface....      3
# 57  amazing app. i have never seen thats type of b...      5
# 58  I forgot my username so i push the forgot user...      2
# 59  very very bad app , after twice finger print s...      1
# 60  its awesome app fund transfer is so easy Thank...      5
# 61  After update today's latest version, when I wa...      1
# 62  superb app I'm so happy that for womens it's a...      5
# 63  very slow app. takes lot of time to open. user...      1
# 64  Worst experience ever from this bank. Can't lo...      1
# 65  taking Back my negetive words....wanna say one...      5
# 66  all process in complete for debit card but deb...      1
# 67  Please update the app, it going slow, while I ...      4
# 68  Used Digibank since its launch .The experience...      5
# 69                bad i cannot use online transaction      1
# 70  fast & handy. More than a year I am using this...      5
# 71  some glitches are there while paying through u...      3
# 72  NICE banking system because it gives unlimited...      5
# 73  Superb app compared to other bank apps. All op...      5
# 74  more attractive and easy access like Axis bank...      3
# 75  this is good service only please give me perso...      5
# 76  Awesome Easy and smart with 0 balance maintain...      5
# 77  easy to operate and quick to respond ....DBS i...      5
# 78  easy to assess, easy transfer, NEED to money t...      4
# 79     very useful application , best online bank app      5
#
# [80 rows x 4 columns]

# %%
import sys
from dbConfig import *
mydb = dbSQL()

# %%
# data = ("sulabh shukla", '2019-02-06', 'nice work it\'s greate...', '3')
# mydb.insert(data)
for data in info:
    print(data)
    mydb.insert(data)
# Out:
# ('A Google user', '24 February 2019', "I don't understand,how I contact to the Bank , I reset my phone and than they ask me for OTP 1st time I enter wrong than 2nd time I enter carefully right OTP and than 3rd time also. Now from 2 weeks my account gives error account is temprory locked and where and whom should I contact I don't understand , please help me", 1)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'A Google user','2019-02-10','I don\'t understand,how I contact to the Bank , I reset my phone and than they ask me for OTP 1st time I enter wrong than 2nd time I enter carefully right OTP and than 3rd time also. Now from 2 weeks my account gives error account is temprory locked and where and whom should I contact I don\'t understand , please help me','1')
# -- successful --
# ('Siva Reddy', '24 February 2019', 'Thank you so much for your immediate and best solution on the issue and shorted out with in one day. Very very happy with the service good banking experience. 😄😆', 4)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Siva Reddy','2019-02-10','Thank you so much for your immediate and best solution on the issue and shorted out with in one day. Very very happy with the service good banking experience. 😄😆','4')
# /home/nawaz/.virtualenvs/AWSComp/lib/python3.5/site-packages/pymysql/cursors.py:170: Warning: (1300, "Invalid utf8 character string: 'Thank ...'")
#   result = self._query(query)
# -- successful --
# ('lokesh jangde', '24 February 2019', 'Amazing app. Yet the app is little bit slow but features of dbs are so awesome that i no longer use any other bank apps.', 5)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'lokesh jangde','2019-02-10','Amazing app. Yet the app is little bit slow but features of dbs are so awesome that i no longer use any other bank apps.','5')
# -- successful --
# ('Ashoo Sachan', '24 February 2019', 'Hi My Name is Anand Prakash.I Am using DigiBank Services From Last 1 And Half Year.I want Say just One Word Its Awsome..!!!', 5)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Ashoo Sachan','2019-02-10','Hi My Name is Anand Prakash.I Am using DigiBank Services From Last 1 And Half Year.I want Say just One Word Its Awsome..!!!','5')
# -- successful --
# ('Rajiv Pandey', '24 February 2019', 'Very smooth and easy to use interface.', 4)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Rajiv Pandey','2019-02-10','Very smooth and easy to use interface.','4')
# -- successful --
# ('Hamid Shaikh', '24 February 2019', 'nice bank', 5)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Hamid Shaikh','2019-02-10','nice bank','5')
# -- successful --
# ('suddhashil mukhuty', '24 February 2019', 'very good', 5)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'suddhashil mukhuty','2019-02-10','very good','5')
# -- successful --
# ('Hemant Desai', '16 February 2019', "This rating is purely for the app and not bank and the services provided. Loved the simple, sort of minimalist approach and yet provide some very essential important features. The higher level of comfort knowing that the security used is a class of it's own. However, this experience can go a long way if the bank were to offer more service and integrate it into the app.", 4)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Hemant Desai','2019-02-10','This rating is purely for the app and not bank and the services provided. Loved the simple, sort of minimalist approach and yet provide some very essential important features. The higher level of comfort knowing that the security used is a class of it\'s own. However, this experience can go a long way if the bank were to offer more service and integrate it into the app.','4')
# -- successful --
# ('Vishal Rex', '17 February 2019', "I have my dbs account which I cant login. I enter my username & password and then it asks me otp. After entering the otp correctly it says linking device... device linking failed and then I'm logged out. I had opened by dbs wallet last year on my same phone. Now when I'm trying to convert it to savings account for months, it shows the same error every time. I cant even create a fresh account on my phone as it shows the error that this devive is already linked with another account.", 1)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Vishal Rex','2019-02-10','I have my dbs account which I cant login. I enter my username & password and then it asks me otp. After entering the otp correctly it says linking device... device linking failed and then I\'m logged out. I had opened by dbs wallet last year on my same phone. Now when I\'m trying to convert it to savings account for months, it shows the same error every time. I cant even create a fresh account on my phone as it shows the error that this devive is already linked with another account.','1')
# -- successful --
# ('Aeshar Manzar', '24 February 2019', 'Hey DBS, you can make your Mobile App better like other mobile banking app ex Kotak Bank App. Your android mobile app is so slow and not smooth. It is got hanged every time i open the app. Make it smoother.', 2)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Aeshar Manzar','2019-02-10','Hey DBS, you can make your Mobile App better like other mobile banking app ex Kotak Bank App. Your android mobile app is so slow and not smooth. It is got hanged every time i open the app. Make it smoother.','2')
# -- successful --
# ('Aniket Jagtap', '20 February 2019', 'this app has issue with PAN varification and there issue resolved system is too much dump,cant trust this bank who dont care there customer.....I had very worst experince with this bank,suggest to go for other banks. dear dbs,stop giving us feedback link in comment.shame on you,customer have to post compliant in app store that show how your system capable of.go and do your work', 1)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Aniket Jagtap','2019-02-10','this app has issue with PAN varification and there issue resolved system is too much dump,cant trust this bank who dont care there customer.....I had very worst experince with this bank,suggest to go for other banks. dear dbs,stop giving us feedback link in comment.shame on you,customer have to post compliant in app store that show how your system capable of.go and do your work','1')
# -- successful --
# ('Madhu Badisha', '18 February 2019', 'you have been saying that "we are coming soon in Hyderabad" for a long time now. if I dont get my KYC done by 2nd March, my account will be frozen I almost lost faith in your statements. Good bye👎', 1)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Madhu Badisha','2019-02-10','you have been saying that \"we are coming soon in Hyderabad\" for a long time now. if I dont get my KYC done by 2nd March, my account will be frozen I almost lost faith in your statements. Good bye👎','1')
# /home/nawaz/.virtualenvs/AWSComp/lib/python3.5/site-packages/pymysql/cursors.py:170: Warning: (1300, "Invalid utf8 character string: 'you ha...'")
#   result = self._query(query)
# -- successful --
# ('Devesh Rastogi', '24 February 2019', "It keeps registering the same device every few days as a new one. Send SMS again and again. Customer care had assured that it's a technical issue and will be sorted out soon. had been working for past one month. But it has started again. Have to register the device again each time I try to login. Very frustrating. wastes time and does not allow txns for 24 hrs each time the phone is re-registered.", 2)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Devesh Rastogi','2019-02-10','It keeps registering the same device every few days as a new one. Send SMS again and again. Customer care had assured that it\'s a technical issue and will be sorted out soon. had been working for past one month. But it has started again. Have to register the device again each time I try to login. Very frustrating. wastes time and does not allow txns for 24 hrs each time the phone is re-registered.','2')
# -- successful --
# ('Krishna Chaitanya Cherukuri', '16 February 2019', 'Good Concept, been using it for more than a year now. The inbuilt security breaks whenever there is an update, so need to reinstall. It is almost impossible to get in touch with support for issues other than the predefined FAQ. Unable to complete MF KYC and no option to contact support or report the issue. Update - 16 Feb 2019 After using more than a year and frequent updates issues have been resolved and the app works without any issues. Keep up the good work team.', 3)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Krishna Chaitanya Cherukuri','2019-02-10','Good Concept, been using it for more than a year now. The inbuilt security breaks whenever there is an update, so need to reinstall. It is almost impossible to get in touch with support for issues other than the predefined FAQ. Unable to complete MF KYC and no option to contact support or report the issue. Update - 16 Feb 2019 After using more than a year and frequent updates issues have been resolved and the app works without any issues. Keep up the good work team.','3')
# -- successful --
# ('kiran nookala', '21 February 2019', 'lost my mobile and do not hold my mobile linked with the app ,sent a mail to customer care to update my new mobile number and no response till now . unfortunately forgot my app password as I did not ise it for many montgs as using a UPI app for quote some time . email response is less ...virtual assistant is useless no customer care no works .even 1* is too much. sent a mail ..no response ...they wanted me to go to tge nearest branch in person and get it done and nearest bank brach is 700 kms .', 1)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'kiran nookala','2019-02-10','lost my mobile and do not hold my mobile linked with the app ,sent a mail to customer care to update my new mobile number and no response till now . unfortunately forgot my app password as I did not ise it for many montgs as using a UPI app for quote some time . email response is less ...virtual assistant is useless no customer care no works .even 1* is too much. sent a mail ..no response ...they wanted me to go to tge nearest branch in person and get it done and nearest bank brach is 700 kms .','1')
# -- successful --
# ('Sudhir Gosavi', '22 February 2019', 'i am happy with the simplicity of this app. But i have been told that there is personal loan facility in the same app where we can see how much personal loan we are eligible.i am not able to find that section in my app, as it is my salary account do there any other app from digi bank for this facility.', 3)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Sudhir Gosavi','2019-02-10','i am happy with the simplicity of this app. But i have been told that there is personal loan facility in the same app where we can see how much personal loan we are eligible.i am not able to find that section in my app, as it is my salary account do there any other app from digi bank for this facility.','3')
# -- successful --
# ('Kiran kumar k', '16 February 2019', "worst app.. can't able to log in..updates are essential for any app.. but frequent updates with a span of 7 days is worst.. more over it wont let to login unless we update.. Dear bank.. please listen to customer issues.. build apps for the users atleast to log in.. forget about enhancements..", 1)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Kiran kumar k','2019-02-10','worst app.. can\'t able to log in..updates are essential for any app.. but frequent updates with a span of 7 days is worst.. more over it wont let to login unless we update.. Dear bank.. please listen to customer issues.. build apps for the users atleast to log in.. forget about enhancements..','1')
# -- successful --
# ('Rahul singh', '21 February 2019', 'This new version ask again abd again to login in sams Phone.Below msgs comes up.... You tried accessing digibank via a new device on 21-02-2019 at 23:43. Please log into digibank and contact us via DIGI Virtual Assistant to report any suspected fraud. please correct this bug.', 5)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Rahul singh','2019-02-10','This new version ask again abd again to login in sams Phone.Below msgs comes up.... You tried accessing digibank via a new device on 21-02-2019 at 23:43. Please log into digibank and contact us via DIGI Virtual Assistant to report any suspected fraud. please correct this bug.','5')
# -- successful --
# ('Sayan Dutta', '24 February 2019', 'now it is really annoying that every time i went to login and it is saying you are try to login from differemt device so otp is needed and mobile sms sent everytime and deducts 1.50 from my sim card.. tell me one thing are you guys stupid,i use same mobile but same thing repeated again and again', 1)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Sayan Dutta','2019-02-10','now it is really annoying that every time i went to login and it is saying you are try to login from differemt device so otp is needed and mobile sms sent everytime and deducts 1.50 from my sim card.. tell me one thing are you guys stupid,i use same mobile but same thing repeated again and again','1')
# -- successful --
# ('Shankar G', '19 February 2019', 'why there is no response regarding digibucks email.. i need to know how to add auto bill pay for mutual fund which i created in digibank app? what i need to do when i would like to speak to customer care? no options available.. pls call me!', 1)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Shankar G','2019-02-10','why there is no response regarding digibucks email.. i need to know how to add auto bill pay for mutual fund which i created in digibank app? what i need to do when i would like to speak to customer care? no options available.. pls call me!','1')
# -- successful --
# ('risabh sharma', '23 February 2019', "Isnt there any other way to open a savings account without the biometric scan.Due to an accident my fingerprints are not scanable through any machine.I called digibank's support team,seems like they are clueless about this.Can you guys help me with this. Thanks.", 1)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'risabh sharma','2019-02-10','Isnt there any other way to open a savings account without the biometric scan.Due to an accident my fingerprints are not scanable through any machine.I called digibank\'s support team,seems like they are clueless about this.Can you guys help me with this. Thanks.','1')
# -- successful --
# ('Prantik Sarkar', '23 February 2019', 'The security is up to standard..the developers need to keep on improving platform integration with better User Interface on the basis of User experience..especially for users who are not tech savvy providing guide and awareness for the masses will make this one of the best microfinance banking..good going', 5)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Prantik Sarkar','2019-02-10','The security is up to standard..the developers need to keep on improving platform integration with better User Interface on the basis of User experience..especially for users who are not tech savvy providing guide and awareness for the masses will make this one of the best microfinance banking..good going','5')
# -- successful --
# ('Shashank Sathe', '19 February 2019', 'Application shows runtime system error and quits... Sad to see that the release is not tested for H2OS and Android handsets running custom ROMs too 👎👎 Addendum: Seems to be working pretty well now. Am liking the app 😃', 5)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Shashank Sathe','2019-02-10','Application shows runtime system error and quits... Sad to see that the release is not tested for H2OS and Android handsets running custom ROMs too 👎👎 Addendum: Seems to be working pretty well now. Am liking the app 😃','5')
# -- successful --
# ('Kaushik Das', '16 February 2019', 'I am really in love with this bank, it was so easy to open the account no hastle at all zero balance savings account was opened all sitting at home. ATM card was sent to my address within 7 days of accout activation. For the biometric verification their representative will visit the address which you fill in online form while opening the account. I have opened a RD account and this bank is giving me 7.5% interest also. I also got Rs 500 as cashback for two successful referrals. Thank you DBS.', 5)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Kaushik Das','2019-02-10','I am really in love with this bank, it was so easy to open the account no hastle at all zero balance savings account was opened all sitting at home. ATM card was sent to my address within 7 days of accout activation. For the biometric verification their representative will visit the address which you fill in online form while opening the account. I have opened a RD account and this bank is giving me 7.5% interest also. I also got Rs 500 as cashback for two successful referrals. Thank you DBS.','5')
# -- successful --
# ('Sivakumar Gobi', '19 February 2019', 'my app is not opening right now.. only a blank screen while opening digibank app.. pathetic app... fix this bug asap', 1)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Sivakumar Gobi','2019-02-10','my app is not opening right now.. only a blank screen while opening digibank app.. pathetic app... fix this bug asap','1')
# -- successful --
# ('Rahul Pandey', '24 February 2019', "One of the best bank in india, can't imagine a bank can provide this much facilities...thanks a lot, if you also collaborate with e-commerce sites then it would be beneficial 🙂", 5)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Rahul Pandey','2019-02-10','One of the best bank in india, can\'t imagine a bank can provide this much facilities...thanks a lot, if you also collaborate with e-commerce sites then it would be beneficial 🙂','5')
# /home/nawaz/.virtualenvs/AWSComp/lib/python3.5/site-packages/pymysql/cursors.py:170: Warning: (1300, "Invalid utf8 character string: 'Applic...'")
#   result = self._query(query)
# /home/nawaz/.virtualenvs/AWSComp/lib/python3.5/site-packages/pymysql/cursors.py:170: Warning: (1300, "Invalid utf8 character string: 'One of...'")
#   result = self._query(query)
# -- successful --
# ('PkiraN PaTIL', '19 February 2019', 'nice eazy application gr8 banking service loved it! suggestions to application developer kindly add recharge options easy way rechargeable from contact not to easy taking time please fix the bug @@@@', 5)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'PkiraN PaTIL','2019-02-10','nice eazy application gr8 banking service loved it! suggestions to application developer kindly add recharge options easy way rechargeable from contact not to easy taking time please fix the bug @@@@','5')
# -- successful --
# ('Vaibhav Dodake', '17 February 2019', 'This bank is comfortable more than we expect. It has so amazing facilities. This bank is my favorite bank and i have opened not only my account but also i have referred all family members and they have also joined with this bank. Loved it ♥️👍🏻', 5)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Vaibhav Dodake','2019-02-10','This bank is comfortable more than we expect. It has so amazing facilities. This bank is my favorite bank and i have opened not only my account but also i have referred all family members and they have also joined with this bank. Loved it ♥️👍🏻','5')
# --- failed --
# ('Sandeep Kumar', '16 February 2019', 'i forgot my user id and password iam past three monts to reset user id and password but it shows every time something went wrong please try again what is issue when you solve this problem plese provide your custmer care number', 1)
# query: INSERT INTO `android_full_comments`  VALUES (NULL, 'Sandeep Kumar','2019-02-10','i forgot my user id and password iam past three monts to reset user id and password but it shows every time something went wrong please try again what is issue when you solve this problem plese provide your custmer care number','1')
# --- failed --
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# /home/nawaz/PycharmProjects/SentimentAnalysis/dbConfig.py in __execute(self, query)
#      34         try:
# ---> 35             self.curs.execute(query)
#      36             result = self.curs.fetchall()
#
# /home/nawaz/.virtualenvs/AWSComp/lib/python3.5/site-packages/pymysql/cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# /home/nawaz/.virtualenvs/AWSComp/lib/python3.5/site-packages/pymysql/cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# /home/nawaz/.virtualenvs/AWSComp/lib/python3.5/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
# --> 516         self._execute_command(COMMAND.COM_QUERY, sql)
#     517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#
# /home/nawaz/.virtualenvs/AWSComp/lib/python3.5/site-packages/pymysql/connections.py in _execute_command(self, command, sql)
#     749         if not self._sock:
# --> 750             raise err.InterfaceError("(0, '')")
#     751
#
# InterfaceError: (0, '')
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-53-c54ed84dad63> in <module>()
#       3 for data in info:
#       4     print(data)
# ----> 5     mydb.insert(data)
#
# /home/nawaz/PycharmProjects/SentimentAnalysis/dbConfig.py in insert(self, rawData)
#      23         #query = """INSERT INTO `android_full_comments`  VALUES (NULL, 'sulabh shukla', '2019-02-05', 'nice work ...', '3');"""
#      24         print('query:', qry % data)
# ---> 25         self.__execute(qry % data)
#      26
#      27     def show(self):
#
# /home/nawaz/PycharmProjects/SentimentAnalysis/dbConfig.py in __execute(self, query)
#      40         except:
#      41             print('--- failed --')
# ---> 42             self.connection.rollback()
#      43         self.connection.close()
#      44
#
# /home/nawaz/.virtualenvs/AWSComp/lib/python3.5/site-packages/pymysql/connections.py in rollback(self)
#     427         in the specification.
#     428         """
# --> 429         self._execute_command(COMMAND.COM_QUERY, "ROLLBACK")
#     430         self._read_ok_packet()
#     431
#
# /home/nawaz/.virtualenvs/AWSComp/lib/python3.5/site-packages/pymysql/connections.py in _execute_command(self, command, sql)
#     748         """
#     749         if not self._sock:
# --> 750             raise err.InterfaceError("(0, '')")
#     751
#     752         # If the last query was unbuffered, make sure it finishes before
#
# InterfaceError: (0, '')

# %%
mydb.show()
# Out:
# --- failed --
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# /home/nawaz/PycharmProjects/SentimentAnalysis/dbConfig.py in __execute(self, query)
#      34         try:
# ---> 35             self.curs.execute(query)
#      36             result = self.curs.fetchall()
#
# /home/nawaz/.virtualenvs/AWSComp/lib/python3.5/site-packages/pymysql/cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# /home/nawaz/.virtualenvs/AWSComp/lib/python3.5/site-packages/pymysql/cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# /home/nawaz/.virtualenvs/AWSComp/lib/python3.5/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
# --> 516         self._execute_command(COMMAND.COM_QUERY, sql)
#     517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#
# /home/nawaz/.virtualenvs/AWSComp/lib/python3.5/site-packages/pymysql/connections.py in _execute_command(self, command, sql)
#     749         if not self._sock:
# --> 750             raise err.InterfaceError("(0, '')")
#     751
#
# InterfaceError: (0, '')
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-56-501c79a8e5ca> in <module>()
# ----> 1 mydb.show()
#
# /home/nawaz/PycharmProjects/SentimentAnalysis/dbConfig.py in show(self)
#      27     def show(self):
#      28         query = """SELECT * FROM `android_full_comments`;"""
# ---> 29         results = self.__execute(query)
#      30         for each in results:
#      31             print(each)
#
# /home/nawaz/PycharmProjects/SentimentAnalysis/dbConfig.py in __execute(self, query)
#      40         except:
#      41             print('--- failed --')
# ---> 42             self.connection.rollback()
#      43         self.connection.close()
#      44
#
# /home/nawaz/.virtualenvs/AWSComp/lib/python3.5/site-packages/pymysql/connections.py in rollback(self)
#     427         in the specification.
#     428         """
# --> 429         self._execute_command(COMMAND.COM_QUERY, "ROLLBACK")
#     430         self._read_ok_packet()
#     431
#
# /home/nawaz/.virtualenvs/AWSComp/lib/python3.5/site-packages/pymysql/connections.py in _execute_command(self, command, sql)
#     748         """
#     749         if not self._sock:
# --> 750             raise err.InterfaceError("(0, '')")
#     751
#     752         # If the last query was unbuffered, make sure it finishes before
#
# InterfaceError: (0, '')

# %%
s = 'I don\'t understand,how I contact to the Bank , I reset my phone and than they ask me for OTP 1st time I enter wrong than 2nd time I enter carefully right OTP and than 3rd time also. Now from 2 weeks my account gives error account is temprory locked and where and whom should I contact I don\'t understand , please help me'
